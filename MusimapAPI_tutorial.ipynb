# %% [markdown]
# # Musimap API v 3.0 Turorial in Python
#
# Documentation: https://developers.musimap.net/documentation/api/usage/introduction
#
# latest update: 30.09.2017

# %%
from __future__ import print_function  # Python 3.x compatibility

import requests
import base64

# %%
# base URL for all API calls to Musimap
base = 'https://api.musimap.net/'

# %% [markdown]
# ### Request your credentials: https://developers.musimap.net/account/clients
#
# click 'Add a client' and request a client_id and a client_secret which you have to set below:

# %%
# ADD YOUR CLIENT ID AND SECRET HERE

client_id = 'put your client id here'
client_secret = 'put your client secret here'

# %% [markdown]
# ## Authenticate
#
# Get an access token. Needed for all further requests.

# %%
call = 'oauth/access_token'
params = {'grant_type': 'client_credentials', 'client_id': client_id, 'client_secret': client_secret} 
resp = requests.post(base + call, params)
resp.status_code
# Out:
# 200

# %%
resp.text
# Out:
# u'{"access_token":"v2mMwFw4vLiASHtKMngN1bjhNsoza8t194HowI8W","type":"Bearer","expires_in":7200}'

# %%
json = resp.json()
token = json['access_token']
token
# Out:
# u'v2mMwFw4vLiASHtKMngN1bjhNsoza8t194HowI8W'

# %% [markdown]
# Currently the 'access_token' needs to provided as a parameter to every GET request.

# %% [markdown]
# ### OAuth Header

# %%
#encode base64

token_enc = base64.standard_b64encode(token)

# %%
# we add this token to extended HTTP request headers (used in all API requests below)
headers = {'Authorization': 'Bearer ' + token_enc}
headers
# Out:
# {'Authorization': 'Bearer djJtTXdGdzR2TGlBU0h0S01uZ04xYmpoTnNvemE4dDE5NEhvd0k4Vw=='}

# %% [markdown]
# ## Genre Search
#
# visual overview: https://genres.musimap.net/

# %%
call = 'genres/search'

genre = 'indie' # indie, calypso 

params = {'name': genre, 'access_token': token}  # token is always passed as an option via ?access_token=
resp = requests.get(base + call, params, headers=headers)
resp.status_code, resp.headers['content-type']
# Out:
# (200, 'application/json')

# %%
# raw response
resp.text
# Out:
# u'{"total":86,"limit":10,"offset":0,"results":[{"uid":"9A620E39-2784-2E3A-1DF0-4743DBC26139","name":"Indie Rock","score":100},{"uid":"1AB1D0C1-7C42-45A1-5D5F-09C0CC9428C9","name":"Indie Pop (and Emo Rock)","score":76.62},{"uid":"D9812B28-C4E8-C3FE-A60D-F1537D2B4E0F","name":"Indie Dance (and Baggy Music)","score":51.08},{"uid":"CE551FEF-4559-C469-B048-BBC2C52C920D","name":"Indian ocean music....","score":25.3},{"uid":"C4B9C657-454F-3C2A-E6C7-961B1BBD7202","name":"Indian Ocean islands","score":21.58},{"uid":"E5575852-1992-4957-EA12-0AEE9EBFB9C3","name":"Indian \\u0026 south asian music....","score":20.26},{"uid":"2E6A459E-D49E-6CCB-9E93-8001112EC45D","name":"Indian Popular  (\\u0026 Bollywood style)","score":17.75},{"uid":"1A98FC93-569B-26CF-354D-238F34D18AE7","name":"Indian Music (classical \\u0026 Traditional)","score":13.19},{"uid":"0670A5BC-BD72-2DA9-ED68-9E96195E5B29","name":"Field Recording \\/ Natural sounds","score":3.84},{"uid":"C233BCD0-48A5-DA0C-C151-6B83E798E71E","name":"Grindcore\\/ Deathgrind","score":3.12}]}'

# %%
# as JSON
json = resp.json()
results = json['results']
results
# Out:
# [{u'name': u'Indie Rock',
#   u'score': 100,
#   u'uid': u'9A620E39-2784-2E3A-1DF0-4743DBC26139'},
#  {u'name': u'Indie Pop (and Emo Rock)',
#   u'score': 76.62,
#   u'uid': u'1AB1D0C1-7C42-45A1-5D5F-09C0CC9428C9'},
#  {u'name': u'Indie Dance (and Baggy Music)',
#   u'score': 51.08,
#   u'uid': u'D9812B28-C4E8-C3FE-A60D-F1537D2B4E0F'},
#  {u'name': u'Indian ocean music....',
#   u'score': 25.3,
#   u'uid': u'CE551FEF-4559-C469-B048-BBC2C52C920D'},
#  {u'name': u'Indian Ocean islands',
#   u'score': 21.58,
#   u'uid': u'C4B9C657-454F-3C2A-E6C7-961B1BBD7202'},
#  {u'name': u'Indian & south asian music....',
#   u'score': 20.26,
#   u'uid': u'E5575852-1992-4957-EA12-0AEE9EBFB9C3'},
#  {u'name': u'Indian Popular  (& Bollywood style)',
#   u'score': 17.75,
#   u'uid': u'2E6A459E-D49E-6CCB-9E93-8001112EC45D'},
#  {u'name': u'Indian Music (classical & Traditional)',
#   u'score': 13.19,
#   u'uid': u'1A98FC93-569B-26CF-354D-238F34D18AE7'},
#  {u'name': u'Field Recording / Natural sounds',
#   u'score': 3.84,
#   u'uid': u'0670A5BC-BD72-2DA9-ED68-9E96195E5B29'},
#  {u'name': u'Grindcore/ Deathgrind',
#   u'score': 3.12,
#   u'uid': u'C233BCD0-48A5-DA0C-C151-6B83E798E71E'}]

# %%
print("List of Genres UIDs and names:")

for res in results:
    print(res['uid'], '\t', res['name'])
# Out:
# List of Genres UIDs and names:
# 9A620E39-2784-2E3A-1DF0-4743DBC26139 	 Indie Rock
# 1AB1D0C1-7C42-45A1-5D5F-09C0CC9428C9 	 Indie Pop (and Emo Rock)
# D9812B28-C4E8-C3FE-A60D-F1537D2B4E0F 	 Indie Dance (and Baggy Music)
# CE551FEF-4559-C469-B048-BBC2C52C920D 	 Indian ocean music....
# C4B9C657-454F-3C2A-E6C7-961B1BBD7202 	 Indian Ocean islands
# E5575852-1992-4957-EA12-0AEE9EBFB9C3 	 Indian & south asian music....
# 2E6A459E-D49E-6CCB-9E93-8001112EC45D 	 Indian Popular  (& Bollywood style)
# 1A98FC93-569B-26CF-354D-238F34D18AE7 	 Indian Music (classical & Traditional)
# 0670A5BC-BD72-2DA9-ED68-9E96195E5B29 	 Field Recording / Natural sounds
# C233BCD0-48A5-DA0C-C151-6B83E798E71E 	 Grindcore/ Deathgrind

# %%
# get just the list of genres names
genres = [res['name'] for res in results]
genres
# Out:
# [u'Indie Rock',
#  u'Indie Pop (and Emo Rock)',
#  u'Indie Dance (and Baggy Music)',
#  u'Indian ocean music....',
#  u'Indian Ocean islands',
#  u'Indian & south asian music....',
#  u'Indian Popular  (& Bollywood style)',
#  u'Indian Music (classical & Traditional)',
#  u'Field Recording / Natural sounds',
#  u'Grindcore/ Deathgrind']

# %% [markdown]
# ## Genre Hierarchy
#
# List genres with all their sub- and sub-sub-genres:

# %%
call = 'genres'

params = {'access_token': token}

resp = requests.get(base + call, params, headers=headers)
resp.status_code
# Out:
# 200

# %%
json = resp.json()
results = json['results']

# %%
json
# Out:
# {u'results': [{u'children': [{u'name': u'Classic experimental electronic & Noise music...',
#      u'uid': u'97861CF3-DCCF-E917-1DA6-C8E64F2DE50A'},
#     {u'name': u'Classical Music...',
#      u'uid': u'64E45EB6-DFA4-B023-9DEA-660961472E65'},
#     {u'name': u'Concerti & symphonies ....',
#      u'uid': u'B735E261-6E5C-567F-5589-C66542C1EEBA'},
#     {u'name': u'Etude & suite....',
#      u'uid': u'0F4A020C-A3CF-8DE1-9661-43DB2FA21F7A'},
#     {u'name': u'March and Military Music',
#      u'uid': u'9D7A3BB2-95F6-302E-FD6F-67D1DAF7640E'},
#     {u'name': u'Minimalist & Contemporary music....',
#      u'uid': u'F78C531B-F8B5-39DA-63ED-A8C4A3C57F33'},
#     {u'name': u'Movie & modern classical....',
#      u'uid': u'B37DC138-81F7-2B6C-36F4-EC2FCA801BAC'},
#     {u'name': u'Operas....', u'uid': u'1B118613-F854-6204-7BAF-46F4E0732A49'},
#     {u'name': u'Sacred music (classical) .... ',
#      u'uid': u'8D7EF246-8CC1-8ED9-1B4D-D912FC126482'},
#     {u'name': u'Sonate /Minuet/scherzo...',
#      u'uid': u'DD44DB55-1BA7-78A7-4730-158C93C99AC2'}],
#    u'name': u'Classical Music...',
#    u'uid': u'64E45EB6-DFA4-B023-9DEA-660961472E65'},
#   {u'children': [{u'name': u'African music....',
#      u'uid': u'86FE3E4E-FD9A-4298-DE52-8469B634E945'},
#     {u'name': u'Bolero', u'uid': u'C6F537D0-DDE6-A70A-BD30-F6751744540B'},
#     {u'name': u'Brazilian music....',
#      u'uid': u'5FD5D64A-423D-967C-D435-5684E3E35B4F'},
#     {u'name': u'Caribbean Islands Roots (Black Creole)',
#      u'uid': u'4CD45056-E867-4636-CC90-50905A04691F'},
#     {u'name': u'Cuban folk...',
#      u'uid': u'CC6BDC6C-006B-50B9-F3DC-AAAE4AF976B0'},
#     {u'name': u'East Asian music....',
#      u'uid': u'8A028102-56FA-0431-84A0-53D0B65D2659'},
#     {u'name': u'East-european & Balkan music....',
#      u'uid': u'F3FA9D30-ABA9-F4BE-91A5-1D828A4F7424'},
#     {u'name': u'Ethno World....',
#      u'uid': u'532FD81C-8725-3911-B5EF-D039F19AD231'},
#     {u'name': u'European music....',
#      u'uid': u'6E75BBAD-4C03-10D4-87DA-29ABEA1E5D35'},
#     {u'name': u'Flamenco', u'uid': u'2B300DCF-6FFE-4C73-AFAD-E6E7A9266773'},
#     {u'name': u'Flamenco', u'uid': u'2B300DCF-6FFE-4C73-AFAD-E6E7A9266773'},
#     {u'name': u'Folk - South American....',
#      u'uid': u'8FD93890-A6F0-6DE9-1387-008D6D0B5AC3'},
#     {u'name': u'Gypsy Music', u'uid': u'B8A6C72E-1A69-02AA-B818-4BE0BFECC9E8'},
#     {u'name': u'Gypsy Music', u'uid': u'B8A6C72E-1A69-02AA-B818-4BE0BFECC9E8'},
#     {u'name': u'Hawa\xefan / Polynesian Folk',
#      u'uid': u'1F8B0973-4398-B03F-E8A3-3E8A00AF10F1'},
#     {u'name': u'Hawa\xefan / Polynesian Folk',
#      u'uid': u'1F8B0973-4398-B03F-E8A3-3E8A00AF10F1'},
#     {u'name': u'Indian & south asian music....',
#      u'uid': u'E5575852-1992-4957-EA12-0AEE9EBFB9C3'},
#     {u'name': u'Indian ocean music....',
#      u'uid': u'CE551FEF-4559-C469-B048-BBC2C52C920D'},
#     {u'name': u'Irish & Celtic Folk',
#      u'uid': u'5E6E8347-35BF-FD12-E54A-C50129916CBE'},
#     {u'name': u'Irish & Celtic Folk',
#      u'uid': u'5E6E8347-35BF-FD12-E54A-C50129916CBE'},
#     {u'name': u'Latin Popular /Latin Dance...',
#      u'uid': u'204A96EA-1E38-459C-4B5F-0C3696D6372A'},
#     {u'name': u'Mediterranean Folk',
#      u'uid': u'F23688BF-373C-0CFA-9FF1-24182D261089'},
#     {u'name': u'Mento & Calypso....',
#      u'uid': u'EAE6D116-AB78-E0E6-9761-3BFB0ABE88DE'},
#     {u'name': u'Merengue', u'uid': u'13B1DC07-87EB-9735-3EBB-3479F0E8B6A5'},
#     {u'name': u'Merengue', u'uid': u'13B1DC07-87EB-9735-3EBB-3479F0E8B6A5'},
#     {u'name': u'Middle east music....',
#      u'uid': u'9234C6B4-77B6-960E-8EF5-F9B281AF68A1'},
#     {u'name': u'Modinha', u'uid': u'A3410143-951C-F5CE-8833-6468292B0CD9'},
#     {u'name': u'Modinha', u'uid': u'A3410143-951C-F5CE-8833-6468292B0CD9'},
#     {u'name': u'Native music....',
#      u'uid': u'95366F15-480B-8D44-BA3F-6C073592742C'},
#     {u'name': u'North-african music....',
#      u'uid': u'24EDBBE7-E948-4A71-A2A0-076E67DC403D'},
#     {u'name': u'Polka', u'uid': u'54385967-82DC-2ACA-3EEC-AF712A73D130'},
#     {u'name': u'Ragga Muffin (Dance Hall)',
#      u'uid': u'E87E2EA5-9E12-F0EA-8B00-04F47430772C'},
#     {u'name': u'Ragga Muffin (Dance Hall)',
#      u'uid': u'E87E2EA5-9E12-F0EA-8B00-04F47430772C'},
#     {u'name': u'Reggae, Ska & Dub....',
#      u'uid': u'078D74DE-F741-CCD7-8901-E04F16E1ED19'},
#     {u'name': u'Rumba', u'uid': u'A51829CC-39E2-C6B5-2FD7-DDCB189CD93C'},
#     {u'name': u'Salsa...', u'uid': u'D3F29710-80CD-53F8-435D-DED97B0C1B45'},
#     {u'name': u'Spanish Popular/ Copla',
#      u'uid': u'6EAED9A1-A46E-C457-1C2B-FF0B9B8942B2'},
#     {u'name': u'Tarentella', u'uid': u'E69635CE-348F-10CC-B74A-3CCF24F399AF'},
#     {u'name': u'World Music (World Pop)',
#      u'uid': u'240DB6A1-E231-26C0-5788-0238C09348B8'},
#     {u'name': u'Zouk', u'uid': u'F589AA94-34F3-1D34-79C5-779AEF887BD0'},
#     {u'name': u'Zouk', u'uid': u'F589AA94-34F3-1D34-79C5-779AEF887BD0'}],
#    u'name': u'Ethno World....',
#    u'uid': u'532FD81C-8725-3911-B5EF-D039F19AD231'},
#   {u'children': [{u'name': u'Afro-Cuban Jazz...',
#      u'uid': u'43E8AFEF-D7DF-B980-AA30-1F7591AC99B8'},
#     {u'name': u'Bop....', u'uid': u'844D04D5-9DAE-6F36-19E4-0B50F8C62A65'},
#     {u'name': u'Contemporary Jazz/Ethno Jazz',
#      u'uid': u'2DE8B317-838C-E043-DED8-8E1EDFFD8928'},
#     {u'name': u'Cool & Creative Jazz....',
#      u'uid': u'480C0C97-343B-9CE8-3262-FC8455629841'},
#     {u'name': u'Dixieland', u'uid': u'EFB54E9F-4EA4-F044-2650-EAA76A6AECE7'},
#     {u'name': u'Exotica', u'uid': u'F0434F3B-84ED-686C-62E0-A3E6D8BD5B86'},
#     {u'name': u'Fanfare & Archaic Jazz',
#      u'uid': u'5A59E604-C0D3-0432-E345-CAB21778837A'},
#     {u'name': u'Free Funk', u'uid': u'3CC176B5-3189-7CEA-1913-C49DA1AE2D25'},
#     {u'name': u'Jazz Fusion & World Jazz...',
#      u'uid': u'4EF50687-6D21-7C45-40E6-AD26A106AA37'},
#     {u'name': u'Jazz Modal', u'uid': u'17A8E7EB-9D55-E4F6-6E06-92A1268444E8'},
#     {u'name': u'Jazz....', u'uid': u'A0323142-88BD-DD9B-2382-445E62BC6FC3'},
#     {u'name': u'M-Base', u'uid': u'DA6FE162-EBB0-90DA-7CA0-F49F79FEA439'},
#     {u'name': u'New Orleans', u'uid': u'058A4655-84A6-B47A-9283-B37CA89769A7'},
#     {u'name': u'Ragtime/Stride piano',
#      u'uid': u'7F0265DA-41D0-5C7B-882D-BD2377AF6966'},
#     {u'name': u'Smooth Jazz', u'uid': u'8BABFE08-DEB5-0017-7E17-8E655AF77F6C'},
#     {u'name': u'Swing & Mainstream....',
#      u'uid': u'B94A39C0-BE12-D197-82FD-BC818BC5261D'},
#     {u'name': u'Third Stream',
#      u'uid': u'595ADE25-656D-EFAF-EC40-2FEBB0B4D003'},
#     {u'name': u'Traditional Pop',
#      u'uid': u'6E8B0346-9F3B-AF0B-3747-20B4B491F067'},
#     {u'name': u'Traditional Pop',
#      u'uid': u'6E8B0346-9F3B-AF0B-3747-20B4B491F067'},
#     {u'name': u'Traditional Pop',
#      u'uid': u'6E8B0346-9F3B-AF0B-3747-20B4B491F067'},
#     {u'name': u'Vocal Jazz', u'uid': u'30183E62-0CAF-D267-F0B0-9FD568FE03C2'},
#     {u'name': u'Vocal Jazz', u'uid': u'30183E62-0CAF-D267-F0B0-9FD568FE03C2'}],
#    u'name': u'Jazz....',
#    u'uid': u'A0323142-88BD-DD9B-2382-445E62BC6FC3'},
#   {u'children': [{u'name': u'Boogie Woogie',
#      u'uid': u'C8E408AB-904B-55BF-30F9-5551FE1DFFB2'},
#     {u'name': u'Cajun & Zydeco',
#      u'uid': u'3E84694B-1258-4CDD-5863-C4E0F71DBF9A'},
#     {u'name': u'Doo Wop', u'uid': u'F42D1ED6-E94B-05F9-9A72-72AB40102E1E'},
#     {u'name': u'Electric Blues (Urban Blues)',
#      u'uid': u'A36EE715-90C9-B616-7222-19EDCC360F4B'},
#     {u'name': u'Gospels & Vocals...',
#      u'uid': u'BC6F3332-1196-B9B4-3460-BF7015936AD7'},
#     {u'name': u'Traditional Blues...',
#      u'uid': u'29019C9B-FB62-CD5A-87D2-F73D587F2C04'}],
#    u'name': u'Blues / Gospel...',
#    u'uid': u'C8F9879F-679D-D539-D994-F94E439F9520'},
#   {u'children': [{u'name': u'Funk and Disco.....',
#      u'uid': u'CD18319A-1191-2D0F-CDF5-9ECFD6017083'},
#     {u'name': u'House...', u'uid': u'E182FEDC-8176-DD95-1A77-FFA75696C594'},
#     {u'name': u'Jungle / Drum & Bass....',
#      u'uid': u'25DE17AC-BE5A-12AB-FDC2-2EB2491B0674'},
#     {u'name': u'Lounge & Acid Jazz....',
#      u'uid': u'751E70C5-0C20-3AEB-863A-F44074FE53DB'},
#     {u'name': u'Rap, Hip Hop & Electro....',
#      u'uid': u'0B85935B-87F3-8E62-9EAB-D7E63D644697'},
#     {u'name': u'Soul...', u'uid': u'104C6F92-C3BC-B973-EA42-3FFEBA21A8EE'},
#     {u'name': u'Techno & Breakbeat....',
#      u'uid': u'6DCFDB78-898D-8781-9AF4-39D056DB6B92'},
#     {u'name': u'Trip Hop & Ambient Groove....',
#      u'uid': u'ED6544E6-8DCA-82F1-05FA-0418886F1190'}],
#    u'name': u'Soul, Funk, Electro, Hip Hop....',
#    u'uid': u'FBF1F078-2EA2-BC79-0401-569C284D1F15'},
#   {u'children': [{u'name': u'Ambient',
#      u'uid': u'DE82FD93-F30A-FF75-7508-13D1EEE38376'},
#     {u'name': u'Country...', u'uid': u'51935AA9-5995-113B-F644-42701F864154'},
#     {u'name': u'Electro Pop &  dance pop...',
#      u'uid': u'05BC2438-A608-CA8E-D787-0ABF17A760A2'},
#     {u'name': u'Folk ( & Protest Song)',
#      u'uid': u'3886B1FA-C84C-1816-45CC-F7250154D7CA'},
#     {u'name': u'Folk...', u'uid': u'F8DB8395-77BC-BBB9-1B37-26DF2B003EE5'},
#     {u'name': u'Gothic & Industrial....',
#      u'uid': u'D17D2E3F-36DC-6D23-3344-243AF7EA97F6'},
#     {u'name': u'international Pop and Rock ....',
#      u'uid': u'391C64A8-2CA0-95BA-2457-21577F0C7C2C'},
#     {u'name': u'Krautrock (Kosmische musik)',
#      u'uid': u'C1056EDF-48FC-017F-C717-40CCC9F3CA36'},
#     {u'name': u'New Age', u'uid': u'CD70D7B0-C34F-9537-66E7-8F3A6980E18E'},
#     {u'name': u'New Wave...', u'uid': u'1D27A043-FCD5-80B2-A5D2-AD5F1F0F4126'},
#     {u'name': u'Pop', u'uid': u'60DF701C-E033-0D36-45C4-E79B32E52784'},
#     {u'name': u'Pop Rock', u'uid': u'117BEC35-0CC3-44EC-A98F-53A3976D9B21'},
#     {u'name': u'Rock / Pop....',
#      u'uid': u'2E18ABA0-6542-2400-9509-3047ED1EEEA3'},
#     {u'name': u'Rock...', u'uid': u'267EE51E-27EF-1E9F-4D75-F3B1B69AECBE'}],
#    u'name': u'Rock / Pop....',
#    u'uid': u'2E18ABA0-6542-2400-9509-3047ED1EEEA3'}]}

# %%
# recursive function
def print_genretree(depth, genretree):
    for genre in genretree:
        print('-' * depth, genre['name']) #, len(genre['children']), "children")
        if 'children' in genre.keys():
            print_genretree(depth+1, genre['children']) # recursive call, 1 level deeper

# %%
print_genretree(0, results)
# Out:
#  Classical Music...
# - Classic experimental electronic & Noise music...
# - Classical Music...
# - Concerti & symphonies ....
# - Etude & suite....
# - March and Military Music
# - Minimalist & Contemporary music....
# - Movie & modern classical....
# - Operas....
# - Sacred music (classical) ....
# - Sonate /Minuet/scherzo...
#  Ethno World....
# - African music....
# - Bolero
# - Brazilian music....
# - Caribbean Islands Roots (Black Creole)
# - Cuban folk...
# - East Asian music....
# - East-european & Balkan music....
# - Ethno World....
# - European music....
# - Flamenco
# - Flamenco
# - Folk - South American....
# - Gypsy Music
# - Gypsy Music
# - Hawaïan / Polynesian Folk
# - Hawaïan / Polynesian Folk
# - Indian & south asian music....
# - Indian ocean music....
# - Irish & Celtic Folk
# - Irish & Celtic Folk
# - Latin Popular /Latin Dance...
# - Mediterranean Folk
# - Mento & Calypso....
# - Merengue
# - Merengue
# - Middle east music....
# - Modinha
# - Modinha
# - Native music....
# - North-african music....
# - Polka
# - Ragga Muffin (Dance Hall)
# - Ragga Muffin (Dance Hall)
# - Reggae, Ska & Dub....
# - Rumba
# - Salsa...
# - Spanish Popular/ Copla
# - Tarentella
# - World Music (World Pop)
# - Zouk
# - Zouk
#  Jazz....
# - Afro-Cuban Jazz...
# - Bop....
# - Contemporary Jazz/Ethno Jazz
# - Cool & Creative Jazz....
# - Dixieland
# - Exotica
# - Fanfare & Archaic Jazz
# - Free Funk
# - Jazz Fusion & World Jazz...
# - Jazz Modal
# - Jazz....
# - M-Base
# - New Orleans
# - Ragtime/Stride piano
# - Smooth Jazz
# - Swing & Mainstream....
# - Third Stream
# - Traditional Pop
# - Traditional Pop
# - Traditional Pop
# - Vocal Jazz
# - Vocal Jazz
#  Blues / Gospel...
# - Boogie Woogie
# - Cajun & Zydeco
# - Doo Wop
# - Electric Blues (Urban Blues)
# - Gospels & Vocals...
# - Traditional Blues...
#  Soul, Funk, Electro, Hip Hop....
# - Funk and Disco.....
# - House...
# - Jungle / Drum & Bass....
# - Lounge & Acid Jazz....
# - Rap, Hip Hop & Electro....
# - Soul...
# - Techno & Breakbeat....
# - Trip Hop & Ambient Groove....
#  Rock / Pop....
# - Ambient
# - Country...
# - Electro Pop &  dance pop...
# - Folk ( & Protest Song)
# - Folk...
# - Gothic & Industrial....
# - international Pop and Rock ....
# - Krautrock (Kosmische musik)
# - New Age
# - New Wave...
# - Pop
# - Pop Rock
# - Rock / Pop....
# - Rock...

# %% [markdown]
# #### The same can be done with mood hierarchy.

# %% [markdown]
# ## Artist Search

# %% [markdown]
# ### Random Artists

# %% [markdown]
# List a certain number of arbitrary artists in database
# (`limit` and `offset` allow pagination):

# %%
call = 'artists/search'
params = {'offset': 0, 'limit': 5, 'access_token': token}

resp = requests.get(base + call, params, headers=headers)
#resp.status_code

json = resp.json()
results = json['results']
results
# Out:
# [{u'nickname': u'DJ Friction (2)',
#   u'score': 100,
#   u'uid': u'AF025211-2121-FD57-3307-1973DDBD587D'},
#  {u'nickname': u'Tammi Lynn',
#   u'score': 100,
#   u'uid': u'CAB27D4B-0714-25A2-7DD9-FC16B7002462'},
#  {u'nickname': u'Gomez',
#   u'score': 100,
#   u'uid': u'C5D1D611-98BD-95F4-C56A-1D5F97B2D4FD'},
#  {u'nickname': u'Sidney Hemphill',
#   u'score': 100,
#   u'uid': u'76A71B8B-C408-2290-4DEC-2B4FA9397620'},
#  {u'nickname': u'Conjunto Rumbavana',
#   u'score': 100,
#   u'uid': u'687FDA87-5B23-D7DA-2C5E-AA22645F4061'}]

# %% [markdown]
# ### Artist Name
#
# Performs matching of name:

# %%
call = 'artists/search'

#artist = 'Avicii'
artist = 'Rihanna' #Eminem'

#params = {'name': artist, 'access_token': token} # DOES NOT WORK!
params = {'nickname': artist, 'access_token': token} # nickname is the rigth keyword

resp = requests.get(base + call, params, headers=headers)
resp.status_code
# Out:
# 200

# %%
json = resp.json()
results = json['results']
for r in results:
    print (str(r['score']) + '\t' + r['uid'] + '\t' + r['nickname'])
# Out:
# 100	07CCB340-9C88-FE9C-0258-0398531415AF	Rihanna
# 83.86	4A853F13-09B0-5445-B0B9-CF38FC5FF051	Rihanna For Piano
# 83.29	6B2A61A4-216C-9DEB-9886-AA54097CFA19	Entre Rihanna
# 67.15	64AB1B9A-A9F9-4E3A-4A95-B361B9BC8C26	Tribute to Eminem & Rihanna
# 67.15	A7074E30-77AA-FE99-09F0-7E933C67CD89	The Rihanna Tributors
# 67.15	AD628A06-EA74-9E1F-6D13-0FA34AA30C31	Tribute to Rihanna
# 66.67	1D2C4A57-068C-9F0A-B35F-4D5481184F95	Rihanna & David Guetta
# 66.67	359CF32C-1FC9-6C54-8625-2EAC9EEAE429	Rihanna Johnson
# 43.13	F184F20E-CCC2-461F-0CB3-16E2162253BC	Tihanna
# 33.17	2A4CEEF9-E2BC-C6DA-B0CC-254EAB5C54A7	Rihan

# %% [markdown]
# ### Artist Name: partial matching with scores:

# %%
call = 'artists/search'
    
for artist in ['Nylon Ho', 'Nylon hotel', 'Nylon Hotel']:
    params = {'nickname': artist, 'access_token': token}
    resp = requests.get(base + call, params, headers=headers)
    #resp.status_code
    json = resp.json()
    results = json['results']
    print ('Search ' + artist + ':') # + '\t', end='')
    if results == []: 
        print("not found.")
    else:
        for r in results:
            print (r['score'], r['nickname'])
# Out:
# Search Nylon Ho:
# 100 Nylon (7)
# 100 Nylon (9)
# 100 Nylon (4)
# 100 Nylon
# 100 Nylon (3)
# 100 Nylon (6)
# 100 Nylon (8)
# 94.06 DJ Nylons
# 94.06 Nylons
# 82.33 Nylons, The (2)
# Search Nylon hotel:
# 100 Nylon Hotel
# 41.16 Hotel Babylon
# 39.52 Vinyl Hotel
# 38.11 Nylon (7)
# 38.11 Nylon (9)
# 38.11 Nylon (4)
# 38.11 Nylon
# 38.11 Nylon (3)
# 38.11 Nylon (6)
# 38.11 Nylon (8)
# Search Nylon Hotel:
# 100 Nylon Hotel
# 41.16 Hotel Babylon
# 39.52 Vinyl Hotel
# 38.11 Nylon (7)
# 38.11 Nylon (9)
# 38.11 Nylon (4)
# 38.11 Nylon
# 38.11 Nylon (3)
# 38.11 Nylon (6)
# 38.11 Nylon (8)

# %% [markdown]
# ## Artist Details
#
# Get Details about an artist: (use above query to get the UID)

# %%
call = 'artists/search'

artist = 'Rihanna'
#artist = 'Adele' # note: other artists come first, the real Adele is #5

# SEARCH BY UID NOT POSSIBLE IN V 2.0
#artist_uid = '07CCB340-9C88-FE9C-0258-0398531415AF' # Rihanna (use above query to get the UID)

# output parameter controls the result and is one of the following:
# details, properties, moods, influences, memberships, discography, social (= ids of other web services)
# (can be combined in comma-separated way)

params = {'nickname': artist, 'output': 'moods', 'access_token': token}
#params = {'nickname': artist, 'output': 'rhythmicmoods'}

resp = requests.get(base + call, params, headers=headers)
resp.status_code
# Out:
# 200

# %%
json = resp.json()
results = json['results']
results
# Out:
# [{u'moods': [{u'importance': 57,
#     u'name': u'Out (Wood)',
#     u'uid': u'C616FB42-6F61-630A-E681-D170F84D1742'},
#    {u'importance': 63,
#     u'name': u'Up (Air)',
#     u'uid': u'C5EF7029-5E84-7F61-B2D1-97D8030F514C'},
#    {u'importance': 2,
#     u'name': u'Above (Fire)',
#     u'uid': u'8E4F875D-7087-64ED-DECA-5295038D9A12'},
#    {u'importance': 13,
#     u'name': u'In/within (Water)',
#     u'uid': u'59B0964A-D326-E5B8-22FE-659B160B8EFF'},
#    {u'importance': 11,
#     u'name': u'On (Ground)',
#     u'uid': u'404BFE84-FF2E-528E-FA9A-47DE57E17BAC'},
#    {u'importance': 7,
#     u'name': u'Down (Metal)',
#     u'uid': u'962C3966-5E12-696F-EF7E-68ABF6A2AFA7'},
#    {u'importance': 1,
#     u'name': u'imagination',
#     u'uid': u'8A74B98A-887C-A9BC-ECDF-A495765820BE'},
#    {u'importance': 1,
#     u'name': u'intellect',
#     u'uid': u'AEC666EF-1869-A54E-18F0-A8F87FB1FEC8'},
#    {u'importance': 2,
#     u'name': u'roots',
#     u'uid': u'2294612B-1233-4F34-B5B6-BDCEA772B1CC'},
#    {u'importance': 5,
#     u'name': u'spirituality',
#     u'uid': u'633210E7-D8C2-9E3C-07A6-03968D0298AC'},
#    {u'importance': 2,
#     u'name': u'coldness',
#     u'uid': u'C56B7569-62B0-9BDA-A116-40DC13465D16'},
#    {u'importance': 12,
#     u'name': u'warrior',
#     u'uid': u'CE8CFA4A-2FD0-6408-7497-C141256C7489'},
#    {u'importance': 18,
#     u'name': u'nourishment',
#     u'uid': u'1BEECA8A-0184-F79B-6924-5188DAF241BD'},
#    {u'importance': 21,
#     u'name': u'love',
#     u'uid': u'6755A82E-689A-E825-EE02-5551736CDB4D'},
#    {u'importance': 8,
#     u'name': u'withdrawal',
#     u'uid': u'F695778E-6475-F312-350C-66114B1BDEC8'},
#    {u'importance': 6,
#     u'name': u'manliness',
#     u'uid': u'92E96FA3-74B5-75B2-27C1-96B7D22D4BBB'},
#    {u'importance': 12,
#     u'name': u'sensibility',
#     u'uid': u'6D5AE713-FA4A-2067-6CC8-B296D29EF57B'},
#    {u'importance': 24,
#     u'name': u'temperament',
#     u'uid': u'C63CE1D1-6178-7984-8629-6C70B180270A'},
#    {u'importance': 50,
#     u'name': u'sexual',
#     u'uid': u'2BE15410-02D8-7604-1972-88C229BE9261'},
#    {u'importance': 60,
#     u'name': u'seductive',
#     u'uid': u'0528C3BF-5461-1249-B384-AFC2FE7F35F2'},
#    {u'importance': 50,
#     u'name': u'soft',
#     u'uid': u'A10C9421-7F41-1C06-268E-2E921D877595'},
#    {u'importance': 30,
#     u'name': u'intense',
#     u'uid': u'88E4D296-5FD6-4A9E-C4E4-5E1DD302CB8B'},
#    {u'importance': 50,
#     u'name': u'sensual',
#     u'uid': u'6C998DCC-6FB2-CC67-1848-535B67DE834E'},
#    {u'importance': 17,
#     u'name': u'sophisticated',
#     u'uid': u'7488B6B9-5EB0-09B7-02C4-21FBC68090FB'},
#    {u'importance': 33,
#     u'name': u'inviting',
#     u'uid': u'11FAD47C-FC9E-7C82-6EA8-14F6F4EE15FA'},
#    {u'importance': 100,
#     u'name': u'friendly',
#     u'uid': u'B0740C6D-7607-3999-9F6C-F66D5E268A50'},
#    {u'importance': 100,
#     u'name': u'confident',
#     u'uid': u'EDFDE5F5-1B7B-5B3E-3C0C-DB3A7996C7C3'},
#    {u'importance': 40,
#     u'name': u'revitalizing',
#     u'uid': u'83E38EEF-C34F-8F75-A789-91BBC6A934E0'},
#    {u'importance': 10,
#     u'name': u'relaxed',
#     u'uid': u'EB81AEF8-DF23-8F56-A5A9-33DE89C845CB'},
#    {u'importance': 88,
#     u'name': u'spirited',
#     u'uid': u'D7D91543-9EF2-2965-D4CC-A7A44D86E442'},
#    {u'importance': 33,
#     u'name': u'spontaneous',
#     u'uid': u'CF7D9EA4-6181-7C04-B025-75A9CFED953A'},
#    {u'importance': 88,
#     u'name': u'witty',
#     u'uid': u'61446A69-ECBF-0C45-D544-0B22F1DC65B0'},
#    {u'importance': 12,
#     u'name': u'kitsch',
#     u'uid': u'29DE99C2-54D1-BDB7-90BA-9ACAE094D4F8'},
#    {u'importance': 33,
#     u'name': u'driving',
#     u'uid': u'AFA2F319-53CC-EC1A-7F30-BF3B0F951AD8'},
#    {u'importance': 100,
#     u'name': u'energetic',
#     u'uid': u'2AD989FA-7E04-54B0-5ED8-924EE47604C0'},
#    {u'importance': 77,
#     u'name': u'dynamism',
#     u'uid': u'1E66C428-F242-7510-C474-303C768870F4'},
#    {u'importance': 10,
#     u'name': u'positive',
#     u'uid': u'10936331-149D-BFEA-F8EA-70CFE8B2836D'},
#    {u'importance': 50,
#     u'name': u'atmospheric',
#     u'uid': u'B6DF5F89-E389-EFD3-2175-7EF6BE38FF43'},
#    {u'importance': 12,
#     u'name': u'wakeful',
#     u'uid': u'B96012D1-87BB-3B0A-62D5-DD749C5F0A25'},
#    {u'importance': 100,
#     u'name': u'fun',
#     u'uid': u'D0F2CB86-0D10-9F76-CF84-750E9CCA6FDA'},
#    {u'importance': 90,
#     u'name': u'festive',
#     u'uid': u'146F0CDC-A8BA-328C-D8FA-129456B7CD1B'},
#    {u'importance': 22,
#     u'name': u'naive',
#     u'uid': u'5B7FD160-AB1A-5916-A939-0FE1411B3B87'},
#    {u'importance': 100,
#     u'name': u'careless',
#     u'uid': u'81AE192F-C3B4-2677-7E35-EB342BD95DBF'},
#    {u'importance': 100,
#     u'name': u'innocent',
#     u'uid': u'19F1971C-46D1-80DB-659D-7ECA064B86B5'},
#    {u'importance': 100,
#     u'name': u'happy',
#     u'uid': u'3A9A56D6-5138-0E95-3B40-4C1C795D1680'},
#    {u'importance': 100,
#     u'name': u'lively',
#     u'uid': u'CEA1F49D-EB15-1EF2-99E8-560ECE45E13B'},
#    {u'importance': 100,
#     u'name': u'free',
#     u'uid': u'6EDA4243-4259-6949-D95E-31F430B9E50F'},
#    {u'importance': 88,
#     u'name': u'happiness',
#     u'uid': u'F05F72AD-E056-CEA2-3BD2-E109EFA0C02B'},
#    {u'importance': 25,
#     u'name': u'calm',
#     u'uid': u'24E39BD5-83BB-7663-ECAD-0AE8BA506987'},
#    {u'importance': 25,
#     u'name': u'serene',
#     u'uid': u'3212CFA7-0B20-4EC4-CD3D-08E291F6620A'},
#    {u'importance': 22,
#     u'name': u'aesthetic',
#     u'uid': u'86712840-0F9C-3AA0-74C5-DFBA82E879D1'},
#    {u'importance': 50,
#     u'name': u'flashy',
#     u'uid': u'B45AD70C-F647-D61D-7542-072AFDE3A526'},
#    {u'importance': 100,
#     u'name': u'impulsive',
#     u'uid': u'C5131D74-04FA-F960-16D8-49570FB115E5'},
#    {u'importance': 100,
#     u'name': u'extravagant',
#     u'uid': u'412E2463-7085-1C4E-B601-B74286465235'},
#    {u'importance': 65,
#     u'name': u'extroversion',
#     u'uid': u'9B58478C-75C0-502B-A8D1-02EB242E8E38'},
#    {u'importance': 50,
#     u'name': u'rebellious',
#     u'uid': u'3CD8FE90-F6BC-B74E-6770-460A4C8DC5F4'},
#    {u'importance': 88,
#     u'name': u'shameless',
#     u'uid': u'A8DE1C29-7A49-4CCA-F84A-DF76EE19A6BD'},
#    {u'importance': 88,
#     u'name': u'loud',
#     u'uid': u'F14B73B9-C320-B6E1-0911-CC6D7837D8F5'},
#    {u'importance': 100,
#     u'name': u'summery',
#     u'uid': u'10B25425-2F30-F0C5-BFFA-EC729F7C9BD6'},
#    {u'importance': 50,
#     u'name': u'charming',
#     u'uid': u'FEFDED43-5D30-3F03-4BB1-B3173C2CFB29'},
#    {u'importance': 33,
#     u'name': u'amicable',
#     u'uid': u'C898EEA1-7475-3902-4F1A-942C9B5E1995'},
#    {u'importance': 10,
#     u'name': u'solar',
#     u'uid': u'6CB564CA-20C6-2F4F-338F-BB987726FF30'},
#    {u'importance': 33,
#     u'name': u'nice',
#     u'uid': u'2B1D85F5-311E-C9FB-2595-170408E48556'},
#    {u'importance': 100,
#     u'name': u'good vibrations',
#     u'uid': u'A03A702B-0EC4-300A-D18C-1542C9023315'},
#    {u'importance': 20,
#     u'name': u'playfulness',
#     u'uid': u'9FFC5764-3EE0-1C96-A840-4EE4FD0F974F'},
#    {u'importance': 55,
#     u'name': u'bright',
#     u'uid': u'04EAD4A4-2A90-BC36-579D-408F47E4F0AC'},
#    {u'importance': 33,
#     u'name': u'powerful',
#     u'uid': u'2A67558C-2FF3-2D44-6DFB-523F80176453'},
#    {u'importance': 77,
#     u'name': u'determined',
#     u'uid': u'0F009D11-53FD-52C7-FCF3-B12A853DA171'},
#    {u'importance': 18,
#     u'name': u' circular',
#     u'uid': u'C5AFA786-A7F8-0AC3-1469-05800BA2537A'},
#    {u'importance': 18,
#     u'name': u'sanitized',
#     u'uid': u'BAFE4EDF-9FDD-0362-66B3-9AA6C6632BBB'},
#    {u'importance': 15,
#     u'name': u'dull',
#     u'uid': u'541463D8-F4EB-E9F4-36EA-482B96DB6807'},
#    {u'importance': 55,
#     u'name': u'organised',
#     u'uid': u'BBC15824-B336-06D6-77D0-8D8A5F0378DD'},
#    {u'importance': 77,
#     u'name': u'precise',
#     u'uid': u'AEEC9A7C-02BD-46AB-ABF5-91817B003BB6'},
#    {u'importance': 22,
#     u'name': u'doubtful',
#     u'uid': u'F296867D-35E5-E26F-87BA-EFB02D6C9871'},
#    {u'importance': 12,
#     u'name': u'pretty',
#     u'uid': u'6CEBAF4C-A524-2EF9-9061-6B5CA6490EA3'},
#    {u'importance': 17,
#     u'name': u'sad',
#     u'uid': u'255CD3EC-C275-09A3-2682-9C8CB4BA375E'},
#    {u'importance': 33,
#     u'name': u'romantic',
#     u'uid': u'9FCC01A9-1AE4-18BD-B5AE-6CD1C7A1D09E'},
#    {u'importance': 33,
#     u'name': u'refined',
#     u'uid': u'80B02A5D-3853-D70D-7336-8E3CC5CB5457'},
#    {u'importance': 24,
#     u'name': u'delicate',
#     u'uid': u'993E5DF5-6A3E-EF42-D236-91F34FB8D1CA'},
#    {u'importance': 62,
#     u'name': u'desirable',
#     u'uid': u'78AB3FB8-D41B-9369-06A9-2FFC278F9DAB'},
#    {u'importance': 21,
#     u'name': u'melancholic',
#     u'uid': u'DD640E4F-94C6-57B3-E373-2D68E5F90CFC'},
#    {u'importance': 24,
#     u'name': u'fragile',
#     u'uid': u'30DF5DDC-46B1-3BD8-0D2D-DC0CC813624B'},
#    {u'importance': 33,
#     u'name': u'sentimental',
#     u'uid': u'104AC159-974B-14CE-7A73-63D91126F4F9'},
#    {u'importance': 24,
#     u'name': u'pretentious',
#     u'uid': u'0599F73B-6A25-E9DA-4668-589A71739A73'}],
#   u'nickname': u'Rihanna',
#   u'score': 100,
#   u'uid': u'07CCB340-9C88-FE9C-0258-0398531415AF'},
#  {u'moods': [],
#   u'nickname': u'Rihanna For Piano',
#   u'score': 83.86,
#   u'uid': u'4A853F13-09B0-5445-B0B9-CF38FC5FF051'},
#  {u'moods': [],
#   u'nickname': u'Entre Rihanna',
#   u'score': 83.29,
#   u'uid': u'6B2A61A4-216C-9DEB-9886-AA54097CFA19'},
#  {u'moods': [],
#   u'nickname': u'Tribute to Eminem & Rihanna',
#   u'score': 67.15,
#   u'uid': u'64AB1B9A-A9F9-4E3A-4A95-B361B9BC8C26'},
#  {u'moods': [],
#   u'nickname': u'The Rihanna Tributors',
#   u'score': 67.15,
#   u'uid': u'A7074E30-77AA-FE99-09F0-7E933C67CD89'},
#  {u'moods': [],
#   u'nickname': u'Tribute to Rihanna',
#   u'score': 67.15,
#   u'uid': u'AD628A06-EA74-9E1F-6D13-0FA34AA30C31'},
#  {u'moods': [],
#   u'nickname': u'Rihanna & David Guetta',
#   u'score': 66.67,
#   u'uid': u'1D2C4A57-068C-9F0A-B35F-4D5481184F95'},
#  {u'moods': [{u'importance': 3,
#     u'name': u'pulsating',
#     u'uid': u'62D58746-0F32-8042-27A8-84F605A48BF9'},
#    {u'importance': 3,
#     u'name': u'epic',
#     u'uid': u'55411BD6-A3B1-0A19-1F69-A5236DF4D240'},
#    {u'importance': 4,
#     u'name': u'cool',
#     u'uid': u'FAB610E7-2224-1ADA-F35C-181D09A46E90'},
#    {u'importance': 5,
#     u'name': u'crazy',
#     u'uid': u'478D1E46-362A-308F-F876-6B6998FA04F2'},
#    {u'importance': 5,
#     u'name': u'wild',
#     u'uid': u'C88C7AFC-FC19-0AF3-D982-546E6864EB1E'},
#    {u'importance': 7,
#     u'name': u'repetitive',
#     u'uid': u'AD0FF4C6-8830-95F7-E7DA-F13DA98BA966'},
#    {u'importance': 7,
#     u'name': u'nice',
#     u'uid': u'2B1D85F5-311E-C9FB-2595-170408E48556'},
#    {u'importance': 7,
#     u'name': u'bright',
#     u'uid': u'04EAD4A4-2A90-BC36-579D-408F47E4F0AC'},
#    {u'importance': 8,
#     u'name': u'upset',
#     u'uid': u'78BCC1B7-FD5E-0031-3703-372B5E3482B0'},
#    {u'importance': 9,
#     u'name': u'rude',
#     u'uid': u'B7004C0A-AB8F-E12B-F1F5-1A8B65867C55'},
#    {u'importance': 10,
#     u'name': u'warm-hearted',
#     u'uid': u'13F575EB-9BD7-BC37-61A8-4E80DED7F1AD'},
#    {u'importance': 11,
#     u'name': u'communicative',
#     u'uid': u'E50384B0-7F88-3104-39A2-184147A58DE2'},
#    {u'importance': 11,
#     u'name': u'biting',
#     u'uid': u'C8CE51CC-9806-10C7-C5DB-5F14EA3D69A1'},
#    {u'importance': 11,
#     u'name': u'impulsive',
#     u'uid': u'C5131D74-04FA-F960-16D8-49570FB115E5'},
#    {u'importance': 11,
#     u'name': u'offensive',
#     u'uid': u'A5EC5598-85AC-830B-B96F-7B6C8B43FDCF'},
#    {u'importance': 11,
#     u'name': u'intense',
#     u'uid': u'88E4D296-5FD6-4A9E-C4E4-5E1DD302CB8B'},
#    {u'importance': 11,
#     u'name': u'exaggerated',
#     u'uid': u'6DCC7FFC-A6D0-8352-8198-97448BCEDF7D'},
#    {u'importance': 11,
#     u'name': u'reckless',
#     u'uid': u'63BBD315-A0CF-3DEC-1192-03FA23766CED'},
#    {u'importance': 11,
#     u'name': u'vengeful',
#     u'uid': u'58C520F0-3293-66D9-8608-2516EDBAD6EF'},
#    {u'importance': 13,
#     u'name': u'spirited',
#     u'uid': u'D7D91543-9EF2-2965-D4CC-A7A44D86E442'},
#    {u'importance': 14,
#     u'name': u'driving',
#     u'uid': u'AFA2F319-53CC-EC1A-7F30-BF3B0F951AD8'},
#    {u'importance': 14,
#     u'name': u'spring',
#     u'uid': u'3FF28522-10B9-0E07-484D-0E17D75DBB34'},
#    {u'importance': 14,
#     u'name': u'energetic',
#     u'uid': u'2AD989FA-7E04-54B0-5ED8-924EE47604C0'},
#    {u'importance': 14,
#     u'name': u'powerful',
#     u'uid': u'2A67558C-2FF3-2D44-6DFB-523F80176453'},
#    {u'importance': 14,
#     u'name': u'determined',
#     u'uid': u'0F009D11-53FD-52C7-FCF3-B12A853DA171'},
#    {u'importance': 15,
#     u'name': u'liberating',
#     u'uid': u'6B2F1E41-F8A9-DBAE-1910-19E99A0A1B55'},
#    {u'importance': 15,
#     u'name': u'sparkling',
#     u'uid': u'E0B561D5-83DF-F347-D5B6-213CA348745A'},
#    {u'importance': 15,
#     u'name': u'romping',
#     u'uid': u'C482D5A7-ED0E-D1BA-34C4-A52B20798975'},
#    {u'importance': 15,
#     u'name': u'exultant',
#     u'uid': u'6ECFA963-98FE-C166-CD1D-EF38E9D5C543'},
#    {u'importance': 16,
#     u'name': u'revitalizing',
#     u'uid': u'83E38EEF-C34F-8F75-A789-91BBC6A934E0'},
#    {u'importance': 16,
#     u'name': u'extravagant',
#     u'uid': u'412E2463-7085-1C4E-B601-B74286465235'},
#    {u'importance': 16,
#     u'name': u'rebellious',
#     u'uid': u'3CD8FE90-F6BC-B74E-6770-460A4C8DC5F4'},
#    {u'importance': 17,
#     u'name': u'playfulness',
#     u'uid': u'9FFC5764-3EE0-1C96-A840-4EE4FD0F974F'},
#    {u'importance': 17,
#     u'name': u'vivacious',
#     u'uid': u'871BFE45-D885-93BF-9D08-669B102FA0F9'},
#    {u'importance': 18,
#     u'name': u'virile',
#     u'uid': u'679B00B2-1FE1-44AF-50B9-10C8961F3048'},
#    {u'importance': 18,
#     u'name': u'active',
#     u'uid': u'6305D635-B152-77EA-BD91-6B8336331BA4'},
#    {u'importance': 19,
#     u'name': u'rhythmic',
#     u'uid': u'D70B66E1-B04C-EBA9-578C-0C1B986CC26F'},
#    {u'importance': 19,
#     u'name': u'bouncy',
#     u'uid': u'139EE6DA-6198-FB8D-479C-021BFB06A80B'}],
#   u'nickname': u'Rihanna Johnson',
#   u'score': 66.67,
#   u'uid': u'359CF32C-1FC9-6C54-8625-2EAC9EEAE429'},
#  {u'moods': [],
#   u'nickname': u'Tihanna',
#   u'score': 43.13,
#   u'uid': u'F184F20E-CCC2-461F-0CB3-16E2162253BC'},
#  {u'moods': [],
#   u'nickname': u'R\u0131han',
#   u'score': 33.17,
#   u'uid': u'C2883220-C1B4-6BC2-78FC-D49045F7E27B'}]

# %%
for r in results:
    print(r['nickname'])
    for m in r['moods']:
        print('  ',m['name'], m['importance'])
# Out:
# Rihanna
#    Out (Wood) 57
#    Up (Air) 63
#    Above (Fire) 2
#    In/within (Water) 13
#    On (Ground) 11
#    Down (Metal) 7
#    imagination 1
#    intellect 1
#    roots 2
#    spirituality 5
#    coldness 2
#    warrior 12
#    nourishment 18
#    love 21
#    withdrawal 8
#    manliness 6
#    sensibility 12
#    temperament 24
#    sexual 50
#    seductive 60
#    soft 50
#    intense 30
#    sensual 50
#    sophisticated 17
#    inviting 33
#    friendly 100
#    confident 100
#    revitalizing 40
#    relaxed 10
#    spirited 88
#    spontaneous 33
#    witty 88
#    kitsch 12
#    driving 33
#    energetic 100
#    dynamism 77
#    positive 10
#    atmospheric 50
#    wakeful 12
#    fun 100
#    festive 90
#    naive 22
#    careless 100
#    innocent 100
#    happy 100
#    lively 100
#    free 100
#    happiness 88
#    calm 25
#    serene 25
#    aesthetic 22
#    flashy 50
#    impulsive 100
#    extravagant 100
#    extroversion 65
#    rebellious 50
#    shameless 88
#    loud 88
#    summery 100
#    charming 50
#    amicable 33
#    solar 10
#    nice 33
#    good vibrations 100
#    playfulness 20
#    bright 55
#    powerful 33
#    determined 77
#     circular 18
#    sanitized 18
#    dull 15
#    organised 55
#    precise 77
#    doubtful 22
#    pretty 12
#    sad 17
#    romantic 33
#    refined 33
#    delicate 24
#    desirable 62
#    melancholic 21
#    fragile 24
#    sentimental 33
#    pretentious 24
# Rihanna For Piano
# Entre Rihanna
# Tribute to Eminem & Rihanna
# The Rihanna Tributors
# Tribute to Rihanna
# Rihanna & David Guetta
# Rihanna Johnson
#    pulsating 3
#    epic 3
#    cool 4
#    crazy 5
#    wild 5
#    repetitive 7
#    nice 7
#    bright 7
#    upset 8
#    rude 9
#    warm-hearted 10
#    communicative 11
#    biting 11
#    impulsive 11
#    offensive 11
#    intense 11
#    exaggerated 11
#    reckless 11
#    vengeful 11
#    spirited 13
#    driving 14
#    spring 14
#    energetic 14
#    powerful 14
#    determined 14
#    liberating 15
#    sparkling 15
#    romping 15
#    exultant 15
#    revitalizing 16
#    extravagant 16
#    rebellious 16
#    playfulness 17
#    vivacious 17
#    virile 18
#    active 18
#    rhythmic 19
#    bouncy 19
# Tihanna
# Rıhan

# %% [markdown]
# ## Artist Recommendation
#
# Use an artist UID that you got from the 'artists/search' call above:

# %%
artist_uid = '07CCB340-9C88-FE9C-0258-0398531415AF' # Rihanna (use query before to get the UID)
#artist_uid = 'D1800E01-04B0-F9D3-91CA-CAC4954717E8'

params = {'limit': 15, 'access_token': token}  # limit: default 10, max. 50

call = 'artists/' + artist_uid + '/recommendations'
call
# Out:
# 'artists/07CCB340-9C88-FE9C-0258-0398531415AF/recommendations'

# %%
#resp = requests.get(base + call, headers=headers)  # without limit
resp = requests.get(base + call, params, headers=headers) # with limit
resp.status_code
# Out:
# 200

# %%
json = resp.json()
results = json['results']

for artist in results:
    print(artist['nickname'], '\t', artist['score'])
# Out:
# Prince  	 41.16

# %% [markdown]
# ## Get Artists by Mood

# %% [markdown]
# ### a) Search for Mood
#
# Search for Mood property to get its UID

# %%
call = 'properties/search'

# moods from Microsoft Cognitive Emotion API:
# Contempt, Disgust, Fear, Happiness, Neutral, Sadness, Surprise

#mood = 'Fear'
mood = 'scared'
#mood = 'melancholic'

category = 'mood'

params = {'name': mood, 'category': category, 'access_token': token}  # limit: default 10, max. 50

resp = requests.get(base + call, params, headers=headers) # with limit
resp.status_code
# Out:
# 200

# %%
json = resp.json()
results = json['results']

results
# Out:
# [{u'category': u'Mood',
#   u'name': u'caring',
#   u'score': 100,
#   u'uid': u'E7C1011A-063E-927F-2203-4CB236BEA20D'},
#  {u'category': u'Mood',
#   u'name': u'careless',
#   u'score': 91.94,
#   u'uid': u'81AE192F-C3B4-2677-7E35-EB342BD95DBF'},
#  {u'category': u'Mood',
#   u'name': u'warm-hearted',
#   u'score': 17.74,
#   u'uid': u'13F575EB-9BD7-BC37-61A8-4E80DED7F1AD'},
#  {u'category': u'Mood',
#   u'name': u'solar',
#   u'score': 12.37,
#   u'uid': u'6CB564CA-20C6-2F4F-338F-BB987726FF30'},
#  {u'category': u'Mood',
#   u'name': u'sharp',
#   u'score': 12.37,
#   u'uid': u'EBD9117A-0D69-66FF-EADB-FDDDE57F158D'},
#  {u'category': u'Mood',
#   u'name': u'cathartic',
#   u'score': 11.29,
#   u'uid': u'B38CF6B8-2C47-96B1-E568-7A7CA3C88A6F'},
#  {u'category': u'Mood',
#   u'name': u'inspired',
#   u'score': 10.22,
#   u'uid': u'57EDB459-31A5-727C-3702-369473AB1521'},
#  {u'category': u'Mood',
#   u'name': u'mannered',
#   u'score': 10.22,
#   u'uid': u'39ACA5F9-01D8-57AA-1E6F-CE6ACF27B6DA'},
#  {u'category': u'Mood',
#   u'name': u'vulgar',
#   u'score': 9.68,
#   u'uid': u'F87F7D70-70F1-D5A1-865C-AEC83B0E6BE7'},
#  {u'category': u'Mood',
#   u'name': u'paranoid',
#   u'score': 7.53,
#   u'uid': u'4EC1DBCB-A22D-D414-9B2B-7F7279BA0470'}]

# %%
# get UID of best-matching mood:

mood = results[0]
print(mood['score'], mood['name'], mood['uid'])
# Out:
# 100 caring E7C1011A-063E-927F-2203-4CB236BEA20D

# %% [markdown]
# ### b) Search for Artists with that Mood

# %%
call = 'artists/search'

min_importance = 50

mood0 =  mood['uid']

#mood0 = 'E7C1011A-063E-927F-2203-4CB236BEA20D' #  caring

#'properties[0][uid]=

#mood0 = 'F1A2E184-90DB-4B01-1DA7-0B0202C10E40'

#&properties[0][importance]=56

# generic properties
params = {'properties[0][uid]': mood0, 'properties[0][importance]': 50,
      'access_token': token}

# moods
params = {'moods[0][uid]': mood0, 'moods[0][importance]': 50, 'output': 'moods',
     'access_token': token}

#'output': 'moods',
    
#params = {'nickname': artist, 'output': 'rhythmicmoods'}

resp = requests.get(base + call, params, headers=headers)
resp.status_code
# Out:
# 200

# %%
json = resp.json()
results = json['results']

print("Mood: ", mood0)
results
# Out:
# Mood:  E7C1011A-063E-927F-2203-4CB236BEA20D
# [{u'moods': [{u'importance': 33,
#     u'name': u'spontaneous',
#     u'uid': u'CF7D9EA4-6181-7C04-B025-75A9CFED953A'},
#    {u'importance': 88,
#     u'name': u'witty',
#     u'uid': u'61446A69-ECBF-0C45-D544-0B22F1DC65B0'},
#    {u'importance': 88,
#     u'name': u'spirited',
#     u'uid': u'D7D91543-9EF2-2965-D4CC-A7A44D86E442'},
#    {u'importance': 18,
#     u'name': u'isolated',
#     u'uid': u'F7948819-E666-5D98-EB31-AACB6ABEEA9D'},
#    {u'importance': 18,
#     u'name': u'rebellious',
#     u'uid': u'3CD8FE90-F6BC-B74E-6770-460A4C8DC5F4'},
#    {u'importance': 50,
#     u'name': u'communicative',
#     u'uid': u'E50384B0-7F88-3104-39A2-184147A58DE2'},
#    {u'importance': 50,
#     u'name': u'positive',
#     u'uid': u'10936331-149D-BFEA-F8EA-70CFE8B2836D'},
#    {u'importance': 66,
#     u'name': u'driving',
#     u'uid': u'AFA2F319-53CC-EC1A-7F30-BF3B0F951AD8'},
#    {u'importance': 22,
#     u'name': u'bitter',
#     u'uid': u'920A2CCD-7C51-B3FF-56A8-B056208C4498'},
#    {u'importance': 100,
#     u'name': u'bittersweet',
#     u'uid': u'62482C44-67CE-6A87-BC39-B6D15D6CF153'},
#    {u'importance': 100,
#     u'name': u'humorous',
#     u'uid': u'5C6AF01E-4C5E-7F5C-4BCF-A70530EBC7AD'},
#    {u'importance': 100,
#     u'name': u'provocative',
#     u'uid': u'1239178A-A38F-AD13-0A21-689206A78F1E'},
#    {u'importance': 100,
#     u'name': u'sensual',
#     u'uid': u'6C998DCC-6FB2-CC67-1848-535B67DE834E'},
#    {u'importance': 20,
#     u'name': u'sanitized',
#     u'uid': u'BAFE4EDF-9FDD-0362-66B3-9AA6C6632BBB'},
#    {u'importance': 55,
#     u'name': u'dull',
#     u'uid': u'541463D8-F4EB-E9F4-36EA-482B96DB6807'},
#    {u'importance': 15,
#     u'name': u'shy',
#     u'uid': u'D94BBF20-AD9E-BC99-5C79-7DD81A21B9C9'},
#    {u'importance': 55,
#     u'name': u'discreet',
#     u'uid': u'6BE29A1A-B01F-AD6A-7CA5-AF3AE60A1419'},
#    {u'importance': 55,
#     u'name': u'inhibited',
#     u'uid': u'BBBEB03B-DE97-EC0E-D6EC-94EF10DED278'},
#    {u'importance': 100,
#     u'name': u'reserved',
#     u'uid': u'7D74E2A1-DDA2-E4F8-D396-71508B8A5053'},
#    {u'importance': 12,
#     u'name': u'peaceful',
#     u'uid': u'5B2C527B-3B75-3F83-9636-5107B3AD96D9'},
#    {u'importance': 40,
#     u'name': u'lazy',
#     u'uid': u'40B9437C-5F2F-7FF2-C23D-2D70A9EDEBA3'},
#    {u'importance': 45,
#     u'name': u'friendly',
#     u'uid': u'B0740C6D-7607-3999-9F6C-F66D5E268A50'},
#    {u'importance': 55,
#     u'name': u'nice',
#     u'uid': u'2B1D85F5-311E-C9FB-2595-170408E48556'},
#    {u'importance': 65,
#     u'name': u'caring',
#     u'uid': u'E7C1011A-063E-927F-2203-4CB236BEA20D'},
#    {u'importance': 70,
#     u'name': u'generous',
#     u'uid': u'0453B572-1071-6CE7-7994-F626E4CA8A95'},
#    {u'importance': 70,
#     u'name': u'round',
#     u'uid': u'F99048F4-BCB1-5C66-C27A-2B853BC76112'},
#    {u'importance': 75,
#     u'name': u'confident',
#     u'uid': u'EDFDE5F5-1B7B-5B3E-3C0C-DB3A7996C7C3'},
#    {u'importance': 80,
#     u'name': u'gentle',
#     u'uid': u'4A834601-9E64-3B0C-5B99-2E533B4746C9'},
#    {u'importance': 80,
#     u'name': u'soothing',
#     u'uid': u'4975732F-3C0C-2F7B-F7A9-7C31398B1569'},
#    {u'importance': 85,
#     u'name': u'warm-hearted',
#     u'uid': u'13F575EB-9BD7-BC37-61A8-4E80DED7F1AD'},
#    {u'importance': 100,
#     u'name': u'cool',
#     u'uid': u'FAB610E7-2224-1ADA-F35C-181D09A46E90'},
#    {u'importance': 100,
#     u'name': u'laid-back',
#     u'uid': u'071FA363-D13D-A011-643C-019F3F34A816'},
#    {u'importance': 22,
#     u'name': u'bright',
#     u'uid': u'04EAD4A4-2A90-BC36-579D-408F47E4F0AC'},
#    {u'importance': 88,
#     u'name': u'disconsolate',
#     u'uid': u'C1DA3F70-3D54-D0B4-102E-C99F21781EE2'},
#    {u'importance': 88,
#     u'name': u'inviting',
#     u'uid': u'11FAD47C-FC9E-7C82-6EA8-14F6F4EE15FA'},
#    {u'importance': 16,
#     u'name': u'hedonist',
#     u'uid': u'D96D8067-DADB-A63B-172F-1F055493EC24'},
#    {u'importance': 12,
#     u'name': u'open-minded',
#     u'uid': u'5DAB7738-1405-04D9-27ED-338BB51280BF'},
#    {u'importance': 100,
#     u'name': u'complex',
#     u'uid': u'6F1D3063-E8E1-C3FF-48C4-FD8C81913DCA'},
#    {u'importance': 33,
#     u'name': u'cerebral',
#     u'uid': u'06CB5405-5031-9D8B-B099-9B6966AFDB6A'},
#    {u'importance': 50,
#     u'name': u'intricate',
#     u'uid': u'A58FF1BE-221B-FB43-B65F-F952EE168128'},
#    {u'importance': 33,
#     u'name': u'organised',
#     u'uid': u'BBC15824-B336-06D6-77D0-8D8A5F0378DD'},
#    {u'importance': 33,
#     u'name': u'methodical',
#     u'uid': u'68F64A5D-CC1E-8E08-7A53-ADEFCBF94626'},
#    {u'importance': 50,
#     u'name': u'difficult',
#     u'uid': u'BD7BA5CE-1C02-ABE0-F767-58EA2B13E98B'},
#    {u'importance': 11,
#     u'name': u'pretty',
#     u'uid': u'6CEBAF4C-A524-2EF9-9061-6B5CA6490EA3'},
#    {u'importance': 11,
#     u'name': u'fragile',
#     u'uid': u'30DF5DDC-46B1-3BD8-0D2D-DC0CC813624B'},
#    {u'importance': 15,
#     u'name': u'ambitious',
#     u'uid': u'6933A010-6D30-A84F-BD02-0B5F385C2B26'},
#    {u'importance': 20,
#     u'name': u'seductive',
#     u'uid': u'0528C3BF-5461-1249-B384-AFC2FE7F35F2'},
#    {u'importance': 25,
#     u'name': u'subtle',
#     u'uid': u'00FF8A09-FAFF-3A5F-84CF-6021DB8272AC'},
#    {u'importance': 77,
#     u'name': u'precise',
#     u'uid': u'AEEC9A7C-02BD-46AB-ABF5-91817B003BB6'},
#    {u'importance': 33,
#     u'name': u'aesthetic',
#     u'uid': u'86712840-0F9C-3AA0-74C5-DFBA82E879D1'},
#    {u'importance': 100,
#     u'name': u'glamourous',
#     u'uid': u'B371AD0E-0532-CBAD-105E-A00B0314E1ED'},
#    {u'importance': 65,
#     u'name': u'sensitive',
#     u'uid': u'5FCD7DCD-9C2C-F96D-1EE8-D9A3EF5886AB'},
#    {u'importance': 65,
#     u'name': u'delicate',
#     u'uid': u'993E5DF5-6A3E-EF42-D236-91F34FB8D1CA'},
#    {u'importance': 65,
#     u'name': u'civilized',
#     u'uid': u'8DB328A2-4E1D-BDF3-B889-86184C58535C'},
#    {u'importance': 66,
#     u'name': u'pretentious',
#     u'uid': u'0599F73B-6A25-E9DA-4668-589A71739A73'},
#    {u'importance': 90,
#     u'name': u'desirable',
#     u'uid': u'78AB3FB8-D41B-9369-06A9-2FFC278F9DAB'},
#    {u'importance': 100,
#     u'name': u'refined',
#     u'uid': u'80B02A5D-3853-D70D-7336-8E3CC5CB5457'},
#    {u'importance': 33,
#     u'name': u'deep',
#     u'uid': u'044BC3C6-9073-B7F4-E171-31F09E59FD73'},
#    {u'importance': 100,
#     u'name': u'melodramatic',
#     u'uid': u'EBD72BDD-08AC-1AF2-B72F-DA30FF41730F'},
#    {u'importance': 100,
#     u'name': u'sophisticated',
#     u'uid': u'7488B6B9-5EB0-09B7-02C4-21FBC68090FB'},
#    {u'importance': 10,
#     u'name': u'doubtful',
#     u'uid': u'F296867D-35E5-E26F-87BA-EFB02D6C9871'},
#    {u'importance': 99,
#     u'name': u'introvert',
#     u'uid': u'6224027F-950C-0C12-BD5B-8541C8F2FDB1'},
#    {u'importance': 88,
#     u'name': u'nostalgic',
#     u'uid': u'FC883530-E528-6A79-B963-B903ADD9FC29'},
#    {u'importance': 50,
#     u'name': u'sentimental',
#     u'uid': u'104AC159-974B-14CE-7A73-63D91126F4F9'},
#    {u'importance': 50,
#     u'name': u'autumnal',
#     u'uid': u'A15DDD60-8379-2972-6DFF-610FDC2343E6'},
#    {u'importance': 100,
#     u'name': u'romantic',
#     u'uid': u'9FCC01A9-1AE4-18BD-B5AE-6CD1C7A1D09E'},
#    {u'importance': 100,
#     u'name': u'soft',
#     u'uid': u'A10C9421-7F41-1C06-268E-2E921D877595'},
#    {u'importance': 50,
#     u'name': u'changing',
#     u'uid': u'F56B6D0A-C6D6-50A1-4150-389E59F67972'},
#    {u'importance': 50,
#     u'name': u'sparkling',
#     u'uid': u'E0B561D5-83DF-F347-D5B6-213CA348745A'},
#    {u'importance': 50,
#     u'name': u'vivacious',
#     u'uid': u'871BFE45-D885-93BF-9D08-669B102FA0F9'},
#    {u'importance': 20,
#     u'name': u'spring',
#     u'uid': u'3FF28522-10B9-0E07-484D-0E17D75DBB34'},
#    {u'importance': 10,
#     u'name': u'upset',
#     u'uid': u'78BCC1B7-FD5E-0031-3703-372B5E3482B0'},
#    {u'importance': 100,
#     u'name': u'fresh',
#     u'uid': u'15417A9D-9D27-B98A-863A-E7498421B08E'},
#    {u'importance': 46,
#     u'name': u'good vibrations',
#     u'uid': u'A03A702B-0EC4-300A-D18C-1542C9023315'},
#    {u'importance': 45,
#     u'name': u'dynamism',
#     u'uid': u'1E66C428-F242-7510-C474-303C768870F4'},
#    {u'importance': 41,
#     u'name': u'Out (Wood)',
#     u'uid': u'C616FB42-6F61-630A-E681-D170F84D1742'}],
#   u'nickname': u'Terry Hall',
#   u'score': 100,
#   u'uid': u'9916FAE1-2CEB-351D-9CB1-613886007F85'},
#  {u'moods': [{u'importance': 24,
#     u'name': u'Up (Air)',
#     u'uid': u'C5EF7029-5E84-7F61-B2D1-97D8030F514C'},
#    {u'importance': 53,
#     u'name': u'sensibility',
#     u'uid': u'6D5AE713-FA4A-2067-6CC8-B296D29EF57B'},
#    {u'importance': 23,
#     u'name': u'temperament',
#     u'uid': u'C63CE1D1-6178-7984-8629-6C70B180270A'},
#    {u'importance': 52,
#     u'name': u'nourishment',
#     u'uid': u'1BEECA8A-0184-F79B-6924-5188DAF241BD'},
#    {u'importance': 44,
#     u'name': u'good vibrations',
#     u'uid': u'A03A702B-0EC4-300A-D18C-1542C9023315'},
#    {u'importance': 39,
#     u'name': u'love',
#     u'uid': u'6755A82E-689A-E825-EE02-5551736CDB4D'},
#    {u'importance': 30,
#     u'name': u'Out (Wood)',
#     u'uid': u'C616FB42-6F61-630A-E681-D170F84D1742'},
#    {u'importance': 37,
#     u'name': u'dynamism',
#     u'uid': u'1E66C428-F242-7510-C474-303C768870F4'},
#    {u'importance': 50,
#     u'name': u'relaxed',
#     u'uid': u'EB81AEF8-DF23-8F56-A5A9-33DE89C845CB'},
#    {u'importance': 100,
#     u'name': u'sad',
#     u'uid': u'255CD3EC-C275-09A3-2682-9C8CB4BA375E'},
#    {u'importance': 12,
#     u'name': u'vicious',
#     u'uid': u'25ECF7DC-8DF6-C4B2-DB84-5D1E28CAE5DD'},
#    {u'importance': 12,
#     u'name': u'burdensome',
#     u'uid': u'28616911-1D92-1E6F-87F6-471C3D6A35B9'},
#    {u'importance': 12,
#     u'name': u'nasty',
#     u'uid': u'E23CDC4A-1991-F807-027E-2EFCAF617B94'},
#    {u'importance': 88,
#     u'name': u'obscure',
#     u'uid': u'7D5104F0-F92B-162F-544F-D6578F14E850'},
#    {u'importance': 77,
#     u'name': u'lightless',
#     u'uid': u'F89DEB79-525C-7DBF-A04C-44FC4833743B'},
#    {u'importance': 22,
#     u'name': u'bitter',
#     u'uid': u'920A2CCD-7C51-B3FF-56A8-B056208C4498'},
#    {u'importance': 100,
#     u'name': u'bittersweet',
#     u'uid': u'62482C44-67CE-6A87-BC39-B6D15D6CF153'},
#    {u'importance': 100,
#     u'name': u'intense',
#     u'uid': u'88E4D296-5FD6-4A9E-C4E4-5E1DD302CB8B'},
#    {u'importance': 12,
#     u'name': u'sensitive',
#     u'uid': u'5FCD7DCD-9C2C-F96D-1EE8-D9A3EF5886AB'},
#    {u'importance': 59,
#     u'name': u'emotional',
#     u'uid': u'5BC6DCE0-5979-2889-25B7-52C05CE2D721'},
#    {u'importance': 78,
#     u'name': u'thoughtful',
#     u'uid': u'446DDB2A-513B-0BDB-B2FD-6F25C401428A'},
#    {u'importance': 12,
#     u'name': u'odd',
#     u'uid': u'A424620A-6B62-5AE4-7201-AECD3BDD9BBB'},
#    {u'importance': 23,
#     u'name': u'daydreaming',
#     u'uid': u'F6BEBC77-7E49-421B-6485-6C27D9EB0E72'},
#    {u'importance': 12,
#     u'name': u'peaceful',
#     u'uid': u'5B2C527B-3B75-3F83-9636-5107B3AD96D9'},
#    {u'importance': 40,
#     u'name': u'lazy',
#     u'uid': u'40B9437C-5F2F-7FF2-C23D-2D70A9EDEBA3'},
#    {u'importance': 45,
#     u'name': u'friendly',
#     u'uid': u'B0740C6D-7607-3999-9F6C-F66D5E268A50'},
#    {u'importance': 55,
#     u'name': u'nice',
#     u'uid': u'2B1D85F5-311E-C9FB-2595-170408E48556'},
#    {u'importance': 65,
#     u'name': u'caring',
#     u'uid': u'E7C1011A-063E-927F-2203-4CB236BEA20D'},
#    {u'importance': 70,
#     u'name': u'generous',
#     u'uid': u'0453B572-1071-6CE7-7994-F626E4CA8A95'},
#    {u'importance': 70,
#     u'name': u'round',
#     u'uid': u'F99048F4-BCB1-5C66-C27A-2B853BC76112'},
#    {u'importance': 75,
#     u'name': u'confident',
#     u'uid': u'EDFDE5F5-1B7B-5B3E-3C0C-DB3A7996C7C3'},
#    {u'importance': 80,
#     u'name': u'inviting',
#     u'uid': u'11FAD47C-FC9E-7C82-6EA8-14F6F4EE15FA'},
#    {u'importance': 80,
#     u'name': u'soothing',
#     u'uid': u'4975732F-3C0C-2F7B-F7A9-7C31398B1569'},
#    {u'importance': 85,
#     u'name': u'warm-hearted',
#     u'uid': u'13F575EB-9BD7-BC37-61A8-4E80DED7F1AD'},
#    {u'importance': 100,
#     u'name': u'soft',
#     u'uid': u'A10C9421-7F41-1C06-268E-2E921D877595'},
#    {u'importance': 100,
#     u'name': u'cool',
#     u'uid': u'FAB610E7-2224-1ADA-F35C-181D09A46E90'},
#    {u'importance': 100,
#     u'name': u'laid-back',
#     u'uid': u'071FA363-D13D-A011-643C-019F3F34A816'},
#    {u'importance': 100,
#     u'name': u'calm',
#     u'uid': u'24E39BD5-83BB-7663-ECAD-0AE8BA506987'},
#    {u'importance': 78,
#     u'name': u'serene',
#     u'uid': u'3212CFA7-0B20-4EC4-CD3D-08E291F6620A'},
#    {u'importance': 100,
#     u'name': u'serious',
#     u'uid': u'C86494B7-B7E3-1492-419C-9A761C3F03C8'},
#    {u'importance': 100,
#     u'name': u'intimate',
#     u'uid': u'A4592BA4-C56E-F654-8939-0772675E3919'},
#    {u'importance': 22,
#     u'name': u'bright',
#     u'uid': u'04EAD4A4-2A90-BC36-579D-408F47E4F0AC'},
#    {u'importance': 88,
#     u'name': u'disconsolate',
#     u'uid': u'C1DA3F70-3D54-D0B4-102E-C99F21781EE2'},
#    {u'importance': 88,
#     u'name': u'nostalgic',
#     u'uid': u'FC883530-E528-6A79-B963-B903ADD9FC29'},
#    {u'importance': 10,
#     u'name': u'doubtful',
#     u'uid': u'F296867D-35E5-E26F-87BA-EFB02D6C9871'},
#    {u'importance': 99,
#     u'name': u'introvert',
#     u'uid': u'6224027F-950C-0C12-BD5B-8541C8F2FDB1'},
#    {u'importance': 100,
#     u'name': u'gentle',
#     u'uid': u'4A834601-9E64-3B0C-5B99-2E533B4746C9'},
#    {u'importance': 100,
#     u'name': u'melancholic',
#     u'uid': u'DD640E4F-94C6-57B3-E373-2D68E5F90CFC'},
#    {u'importance': 100,
#     u'name': u'sentimental',
#     u'uid': u'104AC159-974B-14CE-7A73-63D91126F4F9'},
#    {u'importance': 100,
#     u'name': u'fresh',
#     u'uid': u'15417A9D-9D27-B98A-863A-E7498421B08E'}],
#   u'nickname': u'Sea Wolf',
#   u'score': 100,
#   u'uid': u'19A576DE-FCD6-55D4-7B07-CC3F5D0E78BD'},
#  {u'moods': [{u'importance': 19,
#     u'name': u'intellect',
#     u'uid': u'AEC666EF-1869-A54E-18F0-A8F87FB1FEC8'},
#    {u'importance': 25,
#     u'name': u'epic',
#     u'uid': u'55411BD6-A3B1-0A19-1F69-A5236DF4D240'},
#    {u'importance': 50,
#     u'name': u'happy',
#     u'uid': u'3A9A56D6-5138-0E95-3B40-4C1C795D1680'},
#    {u'importance': 100,
#     u'name': u'bright',
#     u'uid': u'04EAD4A4-2A90-BC36-579D-408F47E4F0AC'},
#    {u'importance': 22,
#     u'name': u'bitter',
#     u'uid': u'920A2CCD-7C51-B3FF-56A8-B056208C4498'},
#    {u'importance': 100,
#     u'name': u'bittersweet',
#     u'uid': u'62482C44-67CE-6A87-BC39-B6D15D6CF153'},
#    {u'importance': 50,
#     u'name': u'meditative',
#     u'uid': u'918D8945-7DE0-2D8E-6190-5171A28719DA'},
#    {u'importance': 12,
#     u'name': u'sensitive',
#     u'uid': u'5FCD7DCD-9C2C-F96D-1EE8-D9A3EF5886AB'},
#    {u'importance': 59,
#     u'name': u'emotional',
#     u'uid': u'5BC6DCE0-5979-2889-25B7-52C05CE2D721'},
#    {u'importance': 78,
#     u'name': u'thoughtful',
#     u'uid': u'446DDB2A-513B-0BDB-B2FD-6F25C401428A'},
#    {u'importance': 12,
#     u'name': u'odd',
#     u'uid': u'A424620A-6B62-5AE4-7201-AECD3BDD9BBB'},
#    {u'importance': 23,
#     u'name': u'daydreaming',
#     u'uid': u'F6BEBC77-7E49-421B-6485-6C27D9EB0E72'},
#    {u'importance': 12,
#     u'name': u'peaceful',
#     u'uid': u'5B2C527B-3B75-3F83-9636-5107B3AD96D9'},
#    {u'importance': 40,
#     u'name': u'lazy',
#     u'uid': u'40B9437C-5F2F-7FF2-C23D-2D70A9EDEBA3'},
#    {u'importance': 65,
#     u'name': u'caring',
#     u'uid': u'E7C1011A-063E-927F-2203-4CB236BEA20D'},
#    {u'importance': 70,
#     u'name': u'generous',
#     u'uid': u'0453B572-1071-6CE7-7994-F626E4CA8A95'},
#    {u'importance': 70,
#     u'name': u'round',
#     u'uid': u'F99048F4-BCB1-5C66-C27A-2B853BC76112'},
#    {u'importance': 75,
#     u'name': u'confident',
#     u'uid': u'EDFDE5F5-1B7B-5B3E-3C0C-DB3A7996C7C3'},
#    {u'importance': 80,
#     u'name': u'gentle',
#     u'uid': u'4A834601-9E64-3B0C-5B99-2E533B4746C9'},
#    {u'importance': 80,
#     u'name': u'soothing',
#     u'uid': u'4975732F-3C0C-2F7B-F7A9-7C31398B1569'},
#    {u'importance': 85,
#     u'name': u'warm-hearted',
#     u'uid': u'13F575EB-9BD7-BC37-61A8-4E80DED7F1AD'},
#    {u'importance': 100,
#     u'name': u'soft',
#     u'uid': u'A10C9421-7F41-1C06-268E-2E921D877595'},
#    {u'importance': 100,
#     u'name': u'cool',
#     u'uid': u'FAB610E7-2224-1ADA-F35C-181D09A46E90'},
#    {u'importance': 100,
#     u'name': u'laid-back',
#     u'uid': u'071FA363-D13D-A011-643C-019F3F34A816'},
#    {u'importance': 100,
#     u'name': u'determined',
#     u'uid': u'0F009D11-53FD-52C7-FCF3-B12A853DA171'},
#    {u'importance': 100,
#     u'name': u'intense',
#     u'uid': u'88E4D296-5FD6-4A9E-C4E4-5E1DD302CB8B'},
#    {u'importance': 30,
#     u'name': u'cerebral',
#     u'uid': u'06CB5405-5031-9D8B-B099-9B6966AFDB6A'},
#    {u'importance': 40,
#     u'name': u'in your face',
#     u'uid': u'7D4A6714-A918-43F7-D1F5-96A1963DFC00'},
#    {u'importance': 100,
#     u'name': u'intimate',
#     u'uid': u'A4592BA4-C56E-F654-8939-0772675E3919'},
#    {u'importance': 100,
#     u'name': u'serious',
#     u'uid': u'C86494B7-B7E3-1492-419C-9A761C3F03C8'},
#    {u'importance': 100,
#     u'name': u'cathartic',
#     u'uid': u'B38CF6B8-2C47-96B1-E568-7A7CA3C88A6F'},
#    {u'importance': 33,
#     u'name': u'deep',
#     u'uid': u'044BC3C6-9073-B7F4-E171-31F09E59FD73'},
#    {u'importance': 33,
#     u'name': u'flashy',
#     u'uid': u'B45AD70C-F647-D61D-7542-072AFDE3A526'},
#    {u'importance': 100,
#     u'name': u'melodramatic',
#     u'uid': u'EBD72BDD-08AC-1AF2-B72F-DA30FF41730F'},
#    {u'importance': 58,
#     u'name': u'proud',
#     u'uid': u'458E616F-1B47-310F-755B-CA07EA19E8B6'},
#    {u'importance': 12,
#     u'name': u'exaggerated',
#     u'uid': u'6DCC7FFC-A6D0-8352-8198-97448BCEDF7D'},
#    {u'importance': 17,
#     u'name': u'mannered',
#     u'uid': u'39ACA5F9-01D8-57AA-1E6F-CE6ACF27B6DA'},
#    {u'importance': 17,
#     u'name': u'extravagant',
#     u'uid': u'412E2463-7085-1C4E-B601-B74286465235'},
#    {u'importance': 78,
#     u'name': u'ambitious',
#     u'uid': u'6933A010-6D30-A84F-BD02-0B5F385C2B26'},
#    {u'importance': 10,
#     u'name': u'doubtful',
#     u'uid': u'F296867D-35E5-E26F-87BA-EFB02D6C9871'},
#    {u'importance': 99,
#     u'name': u'introvert',
#     u'uid': u'6224027F-950C-0C12-BD5B-8541C8F2FDB1'},
#    {u'importance': 100,
#     u'name': u'fragile',
#     u'uid': u'30DF5DDC-46B1-3BD8-0D2D-DC0CC813624B'},
#    {u'importance': 100,
#     u'name': u'vulnerable',
#     u'uid': u'E0546129-DB97-6517-05E7-63C9720E2AE5'},
#    {u'importance': 70,
#     u'name': u'happiness',
#     u'uid': u'F05F72AD-E056-CEA2-3BD2-E109EFA0C02B'},
#    {u'importance': 50,
#     u'name': u'dynamism',
#     u'uid': u'1E66C428-F242-7510-C474-303C768870F4'},
#    {u'importance': 10,
#     u'name': u'crazy',
#     u'uid': u'478D1E46-362A-308F-F876-6B6998FA04F2'},
#    {u'importance': 33,
#     u'name': u'amicable',
#     u'uid': u'C898EEA1-7475-3902-4F1A-942C9B5E1995'},
#    {u'importance': 55,
#     u'name': u'nice',
#     u'uid': u'2B1D85F5-311E-C9FB-2595-170408E48556'},
#    {u'importance': 80,
#     u'name': u'inviting',
#     u'uid': u'11FAD47C-FC9E-7C82-6EA8-14F6F4EE15FA'},
#    {u'importance': 100,
#     u'name': u'friendly',
#     u'uid': u'B0740C6D-7607-3999-9F6C-F66D5E268A50'}],
#   u'nickname': u'Ross Copperman',
#   u'score': 100,
#   u'uid': u'02602E2D-AA03-0AED-1305-25CA33728245'},
#  {u'moods': [{u'importance': 50,
#     u'name': u'communicative',
#     u'uid': u'E50384B0-7F88-3104-39A2-184147A58DE2'},
#    {u'importance': 50,
#     u'name': u'positive',
#     u'uid': u'10936331-149D-BFEA-F8EA-70CFE8B2836D'},
#    {u'importance': 66,
#     u'name': u'driving',
#     u'uid': u'AFA2F319-53CC-EC1A-7F30-BF3B0F951AD8'},
#    {u'importance': 22,
#     u'name': u'bitter',
#     u'uid': u'920A2CCD-7C51-B3FF-56A8-B056208C4498'},
#    {u'importance': 100,
#     u'name': u'bittersweet',
#     u'uid': u'62482C44-67CE-6A87-BC39-B6D15D6CF153'},
#    {u'importance': 100,
#     u'name': u'summery',
#     u'uid': u'10B25425-2F30-F0C5-BFFA-EC729F7C9BD6'},
#    {u'importance': 100,
#     u'name': u'melancholic',
#     u'uid': u'DD640E4F-94C6-57B3-E373-2D68E5F90CFC'},
#    {u'importance': 100,
#     u'name': u'friendly',
#     u'uid': u'B0740C6D-7607-3999-9F6C-F66D5E268A50'},
#    {u'importance': 80,
#     u'name': u'inviting',
#     u'uid': u'11FAD47C-FC9E-7C82-6EA8-14F6F4EE15FA'},
#    {u'importance': 55,
#     u'name': u'nice',
#     u'uid': u'2B1D85F5-311E-C9FB-2595-170408E48556'},
#    {u'importance': 33,
#     u'name': u'amicable',
#     u'uid': u'C898EEA1-7475-3902-4F1A-942C9B5E1995'},
#    {u'importance': 100,
#     u'name': u'soft',
#     u'uid': u'A10C9421-7F41-1C06-268E-2E921D877595'},
#    {u'importance': 100,
#     u'name': u'nostalgic',
#     u'uid': u'FC883530-E528-6A79-B963-B903ADD9FC29'},
#    {u'importance': 33,
#     u'name': u'anxiety',
#     u'uid': u'213BBCF2-F9B1-5AE8-1440-3C8EFAEE7EAF'},
#    {u'importance': 33,
#     u'name': u'monotonous',
#     u'uid': u'738D9847-E8D3-1103-62F3-544560487171'},
#    {u'importance': 100,
#     u'name': u'innocent',
#     u'uid': u'19F1971C-46D1-80DB-659D-7ECA064B86B5'},
#    {u'importance': 22,
#     u'name': u'naive',
#     u'uid': u'5B7FD160-AB1A-5916-A939-0FE1411B3B87'},
#    {u'importance': 22,
#     u'name': u'careless',
#     u'uid': u'81AE192F-C3B4-2677-7E35-EB342BD95DBF'},
#    {u'importance': 100,
#     u'name': u'serious',
#     u'uid': u'C86494B7-B7E3-1492-419C-9A761C3F03C8'},
#    {u'importance': 100,
#     u'name': u'lively',
#     u'uid': u'CEA1F49D-EB15-1EF2-99E8-560ECE45E13B'},
#    {u'importance': 100,
#     u'name': u'laid-back',
#     u'uid': u'071FA363-D13D-A011-643C-019F3F34A816'},
#    {u'importance': 100,
#     u'name': u'cool',
#     u'uid': u'FAB610E7-2224-1ADA-F35C-181D09A46E90'},
#    {u'importance': 85,
#     u'name': u'warm-hearted',
#     u'uid': u'13F575EB-9BD7-BC37-61A8-4E80DED7F1AD'},
#    {u'importance': 80,
#     u'name': u'soothing',
#     u'uid': u'4975732F-3C0C-2F7B-F7A9-7C31398B1569'},
#    {u'importance': 80,
#     u'name': u'gentle',
#     u'uid': u'4A834601-9E64-3B0C-5B99-2E533B4746C9'},
#    {u'importance': 75,
#     u'name': u'confident',
#     u'uid': u'EDFDE5F5-1B7B-5B3E-3C0C-DB3A7996C7C3'},
#    {u'importance': 70,
#     u'name': u'round',
#     u'uid': u'F99048F4-BCB1-5C66-C27A-2B853BC76112'},
#    {u'importance': 70,
#     u'name': u'generous',
#     u'uid': u'0453B572-1071-6CE7-7994-F626E4CA8A95'},
#    {u'importance': 65,
#     u'name': u'caring',
#     u'uid': u'E7C1011A-063E-927F-2203-4CB236BEA20D'},
#    {u'importance': 40,
#     u'name': u'lazy',
#     u'uid': u'40B9437C-5F2F-7FF2-C23D-2D70A9EDEBA3'},
#    {u'importance': 12,
#     u'name': u'peaceful',
#     u'uid': u'5B2C527B-3B75-3F83-9636-5107B3AD96D9'},
#    {u'importance': 88,
#     u'name': u'happiness',
#     u'uid': u'F05F72AD-E056-CEA2-3BD2-E109EFA0C02B'},
#    {u'importance': 58,
#     u'name': u'extravagant',
#     u'uid': u'412E2463-7085-1C4E-B601-B74286465235'},
#    {u'importance': 58,
#     u'name': u'loud',
#     u'uid': u'F14B73B9-C320-B6E1-0911-CC6D7837D8F5'},
#    {u'importance': 50,
#     u'name': u'daydreaming',
#     u'uid': u'F6BEBC77-7E49-421B-6485-6C27D9EB0E72'}],
#   u'nickname': u'Hoolahan',
#   u'score': 100,
#   u'uid': u'776F86E1-86EF-0A94-14C1-990E4342E8C0'},
#  {u'moods': [{u'importance': 26,
#     u'name': u'Up (Air)',
#     u'uid': u'C5EF7029-5E84-7F61-B2D1-97D8030F514C'},
#    {u'importance': 52,
#     u'name': u'good vibrations',
#     u'uid': u'A03A702B-0EC4-300A-D18C-1542C9023315'},
#    {u'importance': 54,
#     u'name': u'love',
#     u'uid': u'6755A82E-689A-E825-EE02-5551736CDB4D'},
#    {u'importance': 35,
#     u'name': u'In/within (Water)',
#     u'uid': u'59B0964A-D326-E5B8-22FE-659B160B8EFF'},
#    {u'importance': 33,
#     u'name': u'Out (Wood)',
#     u'uid': u'C616FB42-6F61-630A-E681-D170F84D1742'},
#    {u'importance': 64,
#     u'name': u'nourishment',
#     u'uid': u'1BEECA8A-0184-F79B-6924-5188DAF241BD'},
#    {u'importance': 29,
#     u'name': u'temperament',
#     u'uid': u'C63CE1D1-6178-7984-8629-6C70B180270A'},
#    {u'importance': 50,
#     u'name': u'atmospheric',
#     u'uid': u'B6DF5F89-E389-EFD3-2175-7EF6BE38FF43'},
#    {u'importance': 25,
#     u'name': u'serene',
#     u'uid': u'3212CFA7-0B20-4EC4-CD3D-08E291F6620A'},
#    {u'importance': 88,
#     u'name': u'calm',
#     u'uid': u'24E39BD5-83BB-7663-ECAD-0AE8BA506987'},
#    {u'importance': 100,
#     u'name': u'sensual',
#     u'uid': u'6C998DCC-6FB2-CC67-1848-535B67DE834E'},
#    {u'importance': 15,
#     u'name': u'shy',
#     u'uid': u'D94BBF20-AD9E-BC99-5C79-7DD81A21B9C9'},
#    {u'importance': 55,
#     u'name': u'discreet',
#     u'uid': u'6BE29A1A-B01F-AD6A-7CA5-AF3AE60A1419'},
#    {u'importance': 55,
#     u'name': u'inhibited',
#     u'uid': u'BBBEB03B-DE97-EC0E-D6EC-94EF10DED278'},
#    {u'importance': 100,
#     u'name': u'reserved',
#     u'uid': u'7D74E2A1-DDA2-E4F8-D396-71508B8A5053'},
#    {u'importance': 20,
#     u'name': u'sanitized',
#     u'uid': u'BAFE4EDF-9FDD-0362-66B3-9AA6C6632BBB'},
#    {u'importance': 12,
#     u'name': u'mannered',
#     u'uid': u'39ACA5F9-01D8-57AA-1E6F-CE6ACF27B6DA'},
#    {u'importance': 12,
#     u'name': u'cerebral',
#     u'uid': u'06CB5405-5031-9D8B-B099-9B6966AFDB6A'},
#    {u'importance': 12,
#     u'name': u'naive',
#     u'uid': u'5B7FD160-AB1A-5916-A939-0FE1411B3B87'},
#    {u'importance': 55,
#     u'name': u'dull',
#     u'uid': u'541463D8-F4EB-E9F4-36EA-482B96DB6807'},
#    {u'importance': 17,
#     u'name': u'methodical',
#     u'uid': u'68F64A5D-CC1E-8E08-7A53-ADEFCBF94626'},
#    {u'importance': 12,
#     u'name': u'peaceful',
#     u'uid': u'5B2C527B-3B75-3F83-9636-5107B3AD96D9'},
#    {u'importance': 40,
#     u'name': u'lazy',
#     u'uid': u'40B9437C-5F2F-7FF2-C23D-2D70A9EDEBA3'},
#    {u'importance': 65,
#     u'name': u'caring',
#     u'uid': u'E7C1011A-063E-927F-2203-4CB236BEA20D'},
#    {u'importance': 70,
#     u'name': u'generous',
#     u'uid': u'0453B572-1071-6CE7-7994-F626E4CA8A95'},
#    {u'importance': 70,
#     u'name': u'round',
#     u'uid': u'F99048F4-BCB1-5C66-C27A-2B853BC76112'},
#    {u'importance': 75,
#     u'name': u'confident',
#     u'uid': u'EDFDE5F5-1B7B-5B3E-3C0C-DB3A7996C7C3'},
#    {u'importance': 85,
#     u'name': u'warm-hearted',
#     u'uid': u'13F575EB-9BD7-BC37-61A8-4E80DED7F1AD'},
#    {u'importance': 100,
#     u'name': u'intimate',
#     u'uid': u'A4592BA4-C56E-F654-8939-0772675E3919'},
#    {u'importance': 27,
#     u'name': u'luminous',
#     u'uid': u'754C7C6E-2651-176F-630A-3F32085A7DA5'},
#    {u'importance': 80,
#     u'name': u'light',
#     u'uid': u'1E089F14-4FA3-839E-C702-1A371051F7E6'},
#    {u'importance': 100,
#     u'name': u'soothing',
#     u'uid': u'4975732F-3C0C-2F7B-F7A9-7C31398B1569'},
#    {u'importance': 11,
#     u'name': u'pretty',
#     u'uid': u'6CEBAF4C-A524-2EF9-9061-6B5CA6490EA3'},
#    {u'importance': 11,
#     u'name': u'fragile',
#     u'uid': u'30DF5DDC-46B1-3BD8-0D2D-DC0CC813624B'},
#    {u'importance': 15,
#     u'name': u'ambitious',
#     u'uid': u'6933A010-6D30-A84F-BD02-0B5F385C2B26'},
#    {u'importance': 20,
#     u'name': u'seductive',
#     u'uid': u'0528C3BF-5461-1249-B384-AFC2FE7F35F2'},
#    {u'importance': 25,
#     u'name': u'subtle',
#     u'uid': u'00FF8A09-FAFF-3A5F-84CF-6021DB8272AC'},
#    {u'importance': 77,
#     u'name': u'precise',
#     u'uid': u'AEEC9A7C-02BD-46AB-ABF5-91817B003BB6'},
#    {u'importance': 33,
#     u'name': u'aesthetic',
#     u'uid': u'86712840-0F9C-3AA0-74C5-DFBA82E879D1'},
#    {u'importance': 51,
#     u'name': u'glamourous',
#     u'uid': u'B371AD0E-0532-CBAD-105E-A00B0314E1ED'},
#    {u'importance': 55,
#     u'name': u'sophisticated',
#     u'uid': u'7488B6B9-5EB0-09B7-02C4-21FBC68090FB'},
#    {u'importance': 65,
#     u'name': u'sensitive',
#     u'uid': u'5FCD7DCD-9C2C-F96D-1EE8-D9A3EF5886AB'},
#    {u'importance': 65,
#     u'name': u'delicate',
#     u'uid': u'993E5DF5-6A3E-EF42-D236-91F34FB8D1CA'},
#    {u'importance': 65,
#     u'name': u'civilized',
#     u'uid': u'8DB328A2-4E1D-BDF3-B889-86184C58535C'},
#    {u'importance': 66,
#     u'name': u'pretentious',
#     u'uid': u'0599F73B-6A25-E9DA-4668-589A71739A73'},
#    {u'importance': 90,
#     u'name': u'desirable',
#     u'uid': u'78AB3FB8-D41B-9369-06A9-2FFC278F9DAB'},
#    {u'importance': 100,
#     u'name': u'refined',
#     u'uid': u'80B02A5D-3853-D70D-7336-8E3CC5CB5457'},
#    {u'importance': 10,
#     u'name': u'doubtful',
#     u'uid': u'F296867D-35E5-E26F-87BA-EFB02D6C9871'},
#    {u'importance': 99,
#     u'name': u'introvert',
#     u'uid': u'6224027F-950C-0C12-BD5B-8541C8F2FDB1'},
#    {u'importance': 100,
#     u'name': u'gentle',
#     u'uid': u'4A834601-9E64-3B0C-5B99-2E533B4746C9'},
#    {u'importance': 100,
#     u'name': u'relaxed',
#     u'uid': u'EB81AEF8-DF23-8F56-A5A9-33DE89C845CB'},
#    {u'importance': 100,
#     u'name': u'cool',
#     u'uid': u'FAB610E7-2224-1ADA-F35C-181D09A46E90'},
#    {u'importance': 66,
#     u'name': u'letting go',
#     u'uid': u'984A4E07-7EBC-717E-BF1E-64E48A5C5960'},
#    {u'importance': 100,
#     u'name': u'laid-back',
#     u'uid': u'071FA363-D13D-A011-643C-019F3F34A816'},
#    {u'importance': 50,
#     u'name': u'nostalgic',
#     u'uid': u'FC883530-E528-6A79-B963-B903ADD9FC29'},
#    {u'importance': 100,
#     u'name': u'sentimental',
#     u'uid': u'104AC159-974B-14CE-7A73-63D91126F4F9'},
#    {u'importance': 50,
#     u'name': u'autumnal',
#     u'uid': u'A15DDD60-8379-2972-6DFF-610FDC2343E6'},
#    {u'importance': 100,
#     u'name': u'romantic',
#     u'uid': u'9FCC01A9-1AE4-18BD-B5AE-6CD1C7A1D09E'},
#    {u'importance': 100,
#     u'name': u'soft',
#     u'uid': u'A10C9421-7F41-1C06-268E-2E921D877595'},
#    {u'importance': 33,
#     u'name': u'amicable',
#     u'uid': u'C898EEA1-7475-3902-4F1A-942C9B5E1995'},
#    {u'importance': 55,
#     u'name': u'nice',
#     u'uid': u'2B1D85F5-311E-C9FB-2595-170408E48556'},
#    {u'importance': 80,
#     u'name': u'inviting',
#     u'uid': u'11FAD47C-FC9E-7C82-6EA8-14F6F4EE15FA'},
#    {u'importance': 100,
#     u'name': u'friendly',
#     u'uid': u'B0740C6D-7607-3999-9F6C-F66D5E268A50'}],
#   u'nickname': u'Eric Marienthal',
#   u'score': 100,
#   u'uid': u'C1C33984-1DCA-C669-EAAF-6C026A6C6479'},
#  {u'moods': [{u'importance': 60,
#     u'name': u'love',
#     u'uid': u'6755A82E-689A-E825-EE02-5551736CDB4D'},
#    {u'importance': 50,
#     u'name': u'dynamism',
#     u'uid': u'1E66C428-F242-7510-C474-303C768870F4'},
#    {u'importance': 48,
#     u'name': u'good vibrations',
#     u'uid': u'A03A702B-0EC4-300A-D18C-1542C9023315'},
#    {u'importance': 35,
#     u'name': u'Up (Air)',
#     u'uid': u'C5EF7029-5E84-7F61-B2D1-97D8030F514C'},
#    {u'importance': 69,
#     u'name': u'happiness',
#     u'uid': u'F05F72AD-E056-CEA2-3BD2-E109EFA0C02B'},
#    {u'importance': 33,
#     u'name': u'temperament',
#     u'uid': u'C63CE1D1-6178-7984-8629-6C70B180270A'},
#    {u'importance': 48,
#     u'name': u'Out (Wood)',
#     u'uid': u'C616FB42-6F61-630A-E681-D170F84D1742'},
#    {u'importance': 33,
#     u'name': u'spontaneous',
#     u'uid': u'CF7D9EA4-6181-7C04-B025-75A9CFED953A'},
#    {u'importance': 88,
#     u'name': u'witty',
#     u'uid': u'61446A69-ECBF-0C45-D544-0B22F1DC65B0'},
#    {u'importance': 88,
#     u'name': u'spirited',
#     u'uid': u'D7D91543-9EF2-2965-D4CC-A7A44D86E442'},
#    {u'importance': 100,
#     u'name': u'soft',
#     u'uid': u'A10C9421-7F41-1C06-268E-2E921D877595'},
#    {u'importance': 50,
#     u'name': u'atmospheric',
#     u'uid': u'B6DF5F89-E389-EFD3-2175-7EF6BE38FF43'},
#    {u'importance': 25,
#     u'name': u'serene',
#     u'uid': u'3212CFA7-0B20-4EC4-CD3D-08E291F6620A'},
#    {u'importance': 25,
#     u'name': u'calm',
#     u'uid': u'24E39BD5-83BB-7663-ECAD-0AE8BA506987'},
#    {u'importance': 25,
#     u'name': u'confident',
#     u'uid': u'EDFDE5F5-1B7B-5B3E-3C0C-DB3A7996C7C3'},
#    {u'importance': 10,
#     u'name': u'relaxed',
#     u'uid': u'EB81AEF8-DF23-8F56-A5A9-33DE89C845CB'},
#    {u'importance': 100,
#     u'name': u'glamourous',
#     u'uid': u'B371AD0E-0532-CBAD-105E-A00B0314E1ED'},
#    {u'importance': 100,
#     u'name': u'careless',
#     u'uid': u'81AE192F-C3B4-2677-7E35-EB342BD95DBF'},
#    {u'importance': 100,
#     u'name': u'fun',
#     u'uid': u'D0F2CB86-0D10-9F76-CF84-750E9CCA6FDA'},
#    {u'importance': 10,
#     u'name': u'pretty',
#     u'uid': u'6CEBAF4C-A524-2EF9-9061-6B5CA6490EA3'},
#    {u'importance': 10,
#     u'name': u'aesthetic',
#     u'uid': u'86712840-0F9C-3AA0-74C5-DFBA82E879D1'},
#    {u'importance': 88,
#     u'name': u'refined',
#     u'uid': u'80B02A5D-3853-D70D-7336-8E3CC5CB5457'},
#    {u'importance': 33,
#     u'name': u'desirable',
#     u'uid': u'78AB3FB8-D41B-9369-06A9-2FFC278F9DAB'},
#    {u'importance': 33,
#     u'name': u'pretentious',
#     u'uid': u'0599F73B-6A25-E9DA-4668-589A71739A73'},
#    {u'importance': 33,
#     u'name': u'powerful',
#     u'uid': u'2A67558C-2FF3-2D44-6DFB-523F80176453'},
#    {u'importance': 33,
#     u'name': u'driving',
#     u'uid': u'AFA2F319-53CC-EC1A-7F30-BF3B0F951AD8'},
#    {u'importance': 40,
#     u'name': u'revitalizing',
#     u'uid': u'83E38EEF-C34F-8F75-A789-91BBC6A934E0'},
#    {u'importance': 100,
#     u'name': u'energetic',
#     u'uid': u'2AD989FA-7E04-54B0-5ED8-924EE47604C0'},
#    {u'importance': 44,
#     u'name': u'disconsolate',
#     u'uid': u'C1DA3F70-3D54-D0B4-102E-C99F21781EE2'},
#    {u'importance': 50,
#     u'name': u'caring',
#     u'uid': u'E7C1011A-063E-927F-2203-4CB236BEA20D'},
#    {u'importance': 100,
#     u'name': u'sophisticated',
#     u'uid': u'7488B6B9-5EB0-09B7-02C4-21FBC68090FB'},
#    {u'importance': 100,
#     u'name': u'extravagant',
#     u'uid': u'412E2463-7085-1C4E-B601-B74286465235'},
#    {u'importance': 100,
#     u'name': u'sentimental',
#     u'uid': u'104AC159-974B-14CE-7A73-63D91126F4F9'},
#    {u'importance': 33,
#     u'name': u'amicable',
#     u'uid': u'C898EEA1-7475-3902-4F1A-942C9B5E1995'},
#    {u'importance': 33,
#     u'name': u'nice',
#     u'uid': u'2B1D85F5-311E-C9FB-2595-170408E48556'},
#    {u'importance': 33,
#     u'name': u'inviting',
#     u'uid': u'11FAD47C-FC9E-7C82-6EA8-14F6F4EE15FA'},
#    {u'importance': 100,
#     u'name': u'friendly',
#     u'uid': u'B0740C6D-7607-3999-9F6C-F66D5E268A50'}],
#   u'nickname': u'Jigsaw',
#   u'score': 100,
#   u'uid': u'EDDC0A70-FDB2-DA88-E4AD-3A4688882D5A'},
#  {u'moods': [{u'importance': 10,
#     u'name': u'positive',
#     u'uid': u'10936331-149D-BFEA-F8EA-70CFE8B2836D'},
#    {u'importance': 90,
#     u'name': u'festive',
#     u'uid': u'146F0CDC-A8BA-328C-D8FA-129456B7CD1B'},
#    {u'importance': 77,
#     u'name': u'introvert',
#     u'uid': u'6224027F-950C-0C12-BD5B-8541C8F2FDB1'},
#    {u'importance': 8,
#     u'name': u'rebellious',
#     u'uid': u'3CD8FE90-F6BC-B74E-6770-460A4C8DC5F4'},
#    {u'importance': 8,
#     u'name': u'wild',
#     u'uid': u'C88C7AFC-FC19-0AF3-D982-546E6864EB1E'},
#    {u'importance': 10,
#     u'name': u'refined',
#     u'uid': u'80B02A5D-3853-D70D-7336-8E3CC5CB5457'},
#    {u'importance': 10,
#     u'name': u'aesthetic',
#     u'uid': u'86712840-0F9C-3AA0-74C5-DFBA82E879D1'},
#    {u'importance': 25,
#     u'name': u'ample',
#     u'uid': u'72B27930-5336-000C-470B-59A6786F254D'},
#    {u'importance': 25,
#     u'name': u'loud',
#     u'uid': u'F14B73B9-C320-B6E1-0911-CC6D7837D8F5'},
#    {u'importance': 28,
#     u'name': u'sentimental',
#     u'uid': u'104AC159-974B-14CE-7A73-63D91126F4F9'},
#    {u'importance': 30,
#     u'name': u'desirable',
#     u'uid': u'78AB3FB8-D41B-9369-06A9-2FFC278F9DAB'},
#    {u'importance': 33,
#     u'name': u'unconventional',
#     u'uid': u'FDB39FC5-786B-412D-9C0E-0BA799B375A4'},
#    {u'importance': 40,
#     u'name': u'romantic',
#     u'uid': u'9FCC01A9-1AE4-18BD-B5AE-6CD1C7A1D09E'},
#    {u'importance': 48,
#     u'name': u'seductive',
#     u'uid': u'0528C3BF-5461-1249-B384-AFC2FE7F35F2'},
#    {u'importance': 50,
#     u'name': u'extravagant',
#     u'uid': u'412E2463-7085-1C4E-B601-B74286465235'},
#    {u'importance': 60,
#     u'name': u'rhythmic',
#     u'uid': u'D70B66E1-B04C-EBA9-578C-0C1B986CC26F'},
#    {u'importance': 70,
#     u'name': u'amicable',
#     u'uid': u'C898EEA1-7475-3902-4F1A-942C9B5E1995'},
#    {u'importance': 75,
#     u'name': u'liberating',
#     u'uid': u'6B2F1E41-F8A9-DBAE-1910-19E99A0A1B55'},
#    {u'importance': 90,
#     u'name': u'energetic',
#     u'uid': u'2AD989FA-7E04-54B0-5ED8-924EE47604C0'},
#    {u'importance': 100,
#     u'name': u'free',
#     u'uid': u'6EDA4243-4259-6949-D95E-31F430B9E50F'},
#    {u'importance': 100,
#     u'name': u'spirited',
#     u'uid': u'D7D91543-9EF2-2965-D4CC-A7A44D86E442'},
#    {u'importance': 100,
#     u'name': u'exultant',
#     u'uid': u'6ECFA963-98FE-C166-CD1D-EF38E9D5C543'},
#    {u'importance': 100,
#     u'name': u'fresh',
#     u'uid': u'15417A9D-9D27-B98A-863A-E7498421B08E'},
#    {u'importance': 100,
#     u'name': u'communicative',
#     u'uid': u'E50384B0-7F88-3104-39A2-184147A58DE2'},
#    {u'importance': 100,
#     u'name': u'charming',
#     u'uid': u'FEFDED43-5D30-3F03-4BB1-B3173C2CFB29'},
#    {u'importance': 100,
#     u'name': u'driving',
#     u'uid': u'AFA2F319-53CC-EC1A-7F30-BF3B0F951AD8'},
#    {u'importance': 100,
#     u'name': u'vivacious',
#     u'uid': u'871BFE45-D885-93BF-9D08-669B102FA0F9'},
#    {u'importance': 100,
#     u'name': u'sparkling',
#     u'uid': u'E0B561D5-83DF-F347-D5B6-213CA348745A'},
#    {u'importance': 100,
#     u'name': u'happy',
#     u'uid': u'3A9A56D6-5138-0E95-3B40-4C1C795D1680'},
#    {u'importance': 33,
#     u'name': u'happiness',
#     u'uid': u'F05F72AD-E056-CEA2-3BD2-E109EFA0C02B'},
#    {u'importance': 100,
#     u'name': u'wakeful',
#     u'uid': u'B96012D1-87BB-3B0A-62D5-DD749C5F0A25'},
#    {u'importance': 22,
#     u'name': u'bitter',
#     u'uid': u'920A2CCD-7C51-B3FF-56A8-B056208C4498'},
#    {u'importance': 100,
#     u'name': u'bittersweet',
#     u'uid': u'62482C44-67CE-6A87-BC39-B6D15D6CF153'},
#    {u'importance': 40,
#     u'name': u'solar',
#     u'uid': u'6CB564CA-20C6-2F4F-338F-BB987726FF30'},
#    {u'importance': 100,
#     u'name': u'intense',
#     u'uid': u'88E4D296-5FD6-4A9E-C4E4-5E1DD302CB8B'},
#    {u'importance': 100,
#     u'name': u'summery',
#     u'uid': u'10B25425-2F30-F0C5-BFFA-EC729F7C9BD6'},
#    {u'importance': 100,
#     u'name': u'fun',
#     u'uid': u'D0F2CB86-0D10-9F76-CF84-750E9CCA6FDA'},
#    {u'importance': 12,
#     u'name': u'peaceful',
#     u'uid': u'5B2C527B-3B75-3F83-9636-5107B3AD96D9'},
#    {u'importance': 40,
#     u'name': u'lazy',
#     u'uid': u'40B9437C-5F2F-7FF2-C23D-2D70A9EDEBA3'},
#    {u'importance': 75,
#     u'name': u'friendly',
#     u'uid': u'B0740C6D-7607-3999-9F6C-F66D5E268A50'},
#    {u'importance': 100,
#     u'name': u'nice',
#     u'uid': u'2B1D85F5-311E-C9FB-2595-170408E48556'},
#    {u'importance': 65,
#     u'name': u'caring',
#     u'uid': u'E7C1011A-063E-927F-2203-4CB236BEA20D'},
#    {u'importance': 70,
#     u'name': u'generous',
#     u'uid': u'0453B572-1071-6CE7-7994-F626E4CA8A95'},
#    {u'importance': 70,
#     u'name': u'round',
#     u'uid': u'F99048F4-BCB1-5C66-C27A-2B853BC76112'},
#    {u'importance': 85,
#     u'name': u'confident',
#     u'uid': u'EDFDE5F5-1B7B-5B3E-3C0C-DB3A7996C7C3'},
#    {u'importance': 80,
#     u'name': u'inviting',
#     u'uid': u'11FAD47C-FC9E-7C82-6EA8-14F6F4EE15FA'},
#    {u'importance': 85,
#     u'name': u'warm-hearted',
#     u'uid': u'13F575EB-9BD7-BC37-61A8-4E80DED7F1AD'},
#    {u'importance': 100,
#     u'name': u'cool',
#     u'uid': u'FAB610E7-2224-1ADA-F35C-181D09A46E90'},
#    {u'importance': 100,
#     u'name': u'laid-back',
#     u'uid': u'071FA363-D13D-A011-643C-019F3F34A816'},
#    {u'importance': 100,
#     u'name': u'intimate',
#     u'uid': u'A4592BA4-C56E-F654-8939-0772675E3919'},
#    {u'importance': 100,
#     u'name': u'serious',
#     u'uid': u'C86494B7-B7E3-1492-419C-9A761C3F03C8'},
#    {u'importance': 90,
#     u'name': u'careless',
#     u'uid': u'81AE192F-C3B4-2677-7E35-EB342BD95DBF'},
#    {u'importance': 100,
#     u'name': u'naive',
#     u'uid': u'5B7FD160-AB1A-5916-A939-0FE1411B3B87'},
#    {u'importance': 100,
#     u'name': u'innocent',
#     u'uid': u'19F1971C-46D1-80DB-659D-7ECA064B86B5'},
#    {u'importance': 100,
#     u'name': u'soothing',
#     u'uid': u'4975732F-3C0C-2F7B-F7A9-7C31398B1569'},
#    {u'importance': 100,
#     u'name': u'autumnal',
#     u'uid': u'A15DDD60-8379-2972-6DFF-610FDC2343E6'},
#    {u'importance': 100,
#     u'name': u'gentle',
#     u'uid': u'4A834601-9E64-3B0C-5B99-2E533B4746C9'},
#    {u'importance': 33,
#     u'name': u'hesitant',
#     u'uid': u'6EA33110-3D34-D405-417A-C16AC9A7CE69'},
#    {u'importance': 33,
#     u'name': u'austere',
#     u'uid': u'327BE7E4-B1F0-D3EE-016C-08C7D85F4F0F'},
#    {u'importance': 23,
#     u'name': u'inhibited',
#     u'uid': u'BBBEB03B-DE97-EC0E-D6EC-94EF10DED278'},
#    {u'importance': 23,
#     u'name': u'shy',
#     u'uid': u'D94BBF20-AD9E-BC99-5C79-7DD81A21B9C9'},
#    {u'importance': 6,
#     u'name': u'isolated',
#     u'uid': u'F7948819-E666-5D98-EB31-AACB6ABEEA9D'},
#    {u'importance': 100,
#     u'name': u'soft',
#     u'uid': u'A10C9421-7F41-1C06-268E-2E921D877595'}],
#   u'nickname': u'Gary Usher',
#   u'score': 100,
#   u'uid': u'29DD524F-622E-75A9-9248-8C467F91E6F5'},
#  {u'moods': [{u'importance': 58,
#     u'name': u'Up (Air)',
#     u'uid': u'C5EF7029-5E84-7F61-B2D1-97D8030F514C'},
#    {u'importance': 87,
#     u'name': u'happiness',
#     u'uid': u'F05F72AD-E056-CEA2-3BD2-E109EFA0C02B'},
#    {u'importance': 49,
#     u'name': u'extroversion',
#     u'uid': u'9B58478C-75C0-502B-A8D1-02EB242E8E38'},
#    {u'importance': 53,
#     u'name': u'dynamism',
#     u'uid': u'1E66C428-F242-7510-C474-303C768870F4'},
#    {u'importance': 45,
#     u'name': u'temperament',
#     u'uid': u'C63CE1D1-6178-7984-8629-6C70B180270A'},
#    {u'importance': 53,
#     u'name': u'good vibrations',
#     u'uid': u'A03A702B-0EC4-300A-D18C-1542C9023315'},
#    {u'importance': 29,
#     u'name': u'In/within (Water)',
#     u'uid': u'59B0964A-D326-E5B8-22FE-659B160B8EFF'},
#    {u'importance': 46,
#     u'name': u'love',
#     u'uid': u'6755A82E-689A-E825-EE02-5551736CDB4D'},
#    {u'importance': 35,
#     u'name': u'Out (Wood)',
#     u'uid': u'C616FB42-6F61-630A-E681-D170F84D1742'},
#    {u'importance': 50,
#     u'name': u'nourishment',
#     u'uid': u'1BEECA8A-0184-F79B-6924-5188DAF241BD'},
#    {u'importance': 12,
#     u'name': u'vicious',
#     u'uid': u'25ECF7DC-8DF6-C4B2-DB84-5D1E28CAE5DD'},
#    {u'importance': 12,
#     u'name': u'burdensome',
#     u'uid': u'28616911-1D92-1E6F-87F6-471C3D6A35B9'},
#    {u'importance': 12,
#     u'name': u'nasty',
#     u'uid': u'E23CDC4A-1991-F807-027E-2EFCAF617B94'},
#    {u'importance': 33,
#     u'name': u' resourceful',
#     u'uid': u'B4DF9818-FAB2-528F-A427-4B82652C9BBC'},
#    {u'importance': 77,
#     u'name': u'essential',
#     u'uid': u'8B3FF0C8-C5D1-56ED-CA65-49909BCA2D81'},
#    {u'importance': 100,
#     u'name': u'fun',
#     u'uid': u'D0F2CB86-0D10-9F76-CF84-750E9CCA6FDA'},
#    {u'importance': 100,
#     u'name': u'exultant',
#     u'uid': u'6ECFA963-98FE-C166-CD1D-EF38E9D5C543'},
#    {u'importance': 100,
#     u'name': u'sensual',
#     u'uid': u'6C998DCC-6FB2-CC67-1848-535B67DE834E'},
#    {u'importance': 10,
#     u'name': u'pretty',
#     u'uid': u'6CEBAF4C-A524-2EF9-9061-6B5CA6490EA3'},
#    {u'importance': 10,
#     u'name': u'aesthetic',
#     u'uid': u'86712840-0F9C-3AA0-74C5-DFBA82E879D1'},
#    {u'importance': 88,
#     u'name': u'refined',
#     u'uid': u'80B02A5D-3853-D70D-7336-8E3CC5CB5457'},
#    {u'importance': 33,
#     u'name': u'desirable',
#     u'uid': u'78AB3FB8-D41B-9369-06A9-2FFC278F9DAB'},
#    {u'importance': 33,
#     u'name': u'pretentious',
#     u'uid': u'0599F73B-6A25-E9DA-4668-589A71739A73'},
#    {u'importance': 12,
#     u'name': u'peaceful',
#     u'uid': u'5B2C527B-3B75-3F83-9636-5107B3AD96D9'},
#    {u'importance': 40,
#     u'name': u'lazy',
#     u'uid': u'40B9437C-5F2F-7FF2-C23D-2D70A9EDEBA3'},
#    {u'importance': 45,
#     u'name': u'friendly',
#     u'uid': u'B0740C6D-7607-3999-9F6C-F66D5E268A50'},
#    {u'importance': 55,
#     u'name': u'nice',
#     u'uid': u'2B1D85F5-311E-C9FB-2595-170408E48556'},
#    {u'importance': 65,
#     u'name': u'caring',
#     u'uid': u'E7C1011A-063E-927F-2203-4CB236BEA20D'},
#    {u'importance': 70,
#     u'name': u'generous',
#     u'uid': u'0453B572-1071-6CE7-7994-F626E4CA8A95'},
#    {u'importance': 70,
#     u'name': u'round',
#     u'uid': u'F99048F4-BCB1-5C66-C27A-2B853BC76112'},
#    {u'importance': 80,
#     u'name': u'gentle',
#     u'uid': u'4A834601-9E64-3B0C-5B99-2E533B4746C9'},
#    {u'importance': 80,
#     u'name': u'inviting',
#     u'uid': u'11FAD47C-FC9E-7C82-6EA8-14F6F4EE15FA'},
#    {u'importance': 80,
#     u'name': u'soothing',
#     u'uid': u'4975732F-3C0C-2F7B-F7A9-7C31398B1569'},
#    {u'importance': 85,
#     u'name': u'warm-hearted',
#     u'uid': u'13F575EB-9BD7-BC37-61A8-4E80DED7F1AD'},
#    {u'importance': 100,
#     u'name': u'soft',
#     u'uid': u'A10C9421-7F41-1C06-268E-2E921D877595'},
#    {u'importance': 23,
#     u'name': u'free',
#     u'uid': u'6EDA4243-4259-6949-D95E-31F430B9E50F'},
#    {u'importance': 80,
#     u'name': u'letting go',
#     u'uid': u'984A4E07-7EBC-717E-BF1E-64E48A5C5960'},
#    {u'importance': 100,
#     u'name': u'laid-back',
#     u'uid': u'071FA363-D13D-A011-643C-019F3F34A816'},
#    {u'importance': 80,
#     u'name': u'loose',
#     u'uid': u'1C1BC590-FD60-DDBA-D89E-558BE4CB6C68'},
#    {u'importance': 22,
#     u'name': u'bright',
#     u'uid': u'04EAD4A4-2A90-BC36-579D-408F47E4F0AC'},
#    {u'importance': 88,
#     u'name': u'disconsolate',
#     u'uid': u'C1DA3F70-3D54-D0B4-102E-C99F21781EE2'},
#    {u'importance': 33,
#     u'name': u'bravado',
#     u'uid': u'5E579C46-BD0F-D09B-1B52-498CAE52A095'},
#    {u'importance': 33,
#     u'name': u'tuned',
#     u'uid': u'6601B9A2-5928-401D-52D3-3BE0A3A04450'},
#    {u'importance': 33,
#     u'name': u'shameless',
#     u'uid': u'A8DE1C29-7A49-4CCA-F84A-DF76EE19A6BD'},
#    {u'importance': 100,
#     u'name': u'cool',
#     u'uid': u'FAB610E7-2224-1ADA-F35C-181D09A46E90'},
#    {u'importance': 75,
#     u'name': u'confident',
#     u'uid': u'EDFDE5F5-1B7B-5B3E-3C0C-DB3A7996C7C3'},
#    {u'importance': 100,
#     u'name': u'extravagant',
#     u'uid': u'412E2463-7085-1C4E-B601-B74286465235'},
#    {u'importance': 88,
#     u'name': u'nostalgic',
#     u'uid': u'FC883530-E528-6A79-B963-B903ADD9FC29'},
#    {u'importance': 50,
#     u'name': u'sentimental',
#     u'uid': u'104AC159-974B-14CE-7A73-63D91126F4F9'},
#    {u'importance': 50,
#     u'name': u'autumnal',
#     u'uid': u'A15DDD60-8379-2972-6DFF-610FDC2343E6'},
#    {u'importance': 100,
#     u'name': u'romantic',
#     u'uid': u'9FCC01A9-1AE4-18BD-B5AE-6CD1C7A1D09E'}],
#   u'nickname': u'Chuck Willis',
#   u'score': 100,
#   u'uid': u'75037770-7EBE-F196-C992-A1DB98A1DFE4'},
#  {u'moods': [{u'importance': 51,
#     u'name': u'sensibility',
#     u'uid': u'6D5AE713-FA4A-2067-6CC8-B296D29EF57B'},
#    {u'importance': 51,
#     u'name': u'love',
#     u'uid': u'6755A82E-689A-E825-EE02-5551736CDB4D'},
#    {u'importance': 31,
#     u'name': u'temperament',
#     u'uid': u'C63CE1D1-6178-7984-8629-6C70B180270A'},
#    {u'importance': 43,
#     u'name': u'roots',
#     u'uid': u'2294612B-1233-4F34-B5B6-BDCEA772B1CC'},
#    {u'importance': 51,
#     u'name': u'On (Ground)',
#     u'uid': u'404BFE84-FF2E-528E-FA9A-47DE57E17BAC'},
#    {u'importance': 51,
#     u'name': u'Down (Metal)',
#     u'uid': u'962C3966-5E12-696F-EF7E-68ABF6A2AFA7'},
#    {u'importance': 51,
#     u'name': u'nourishment',
#     u'uid': u'1BEECA8A-0184-F79B-6924-5188DAF241BD'},
#    {u'importance': 22,
#     u'name': u'In/within (Water)',
#     u'uid': u'59B0964A-D326-E5B8-22FE-659B160B8EFF'},
#    {u'importance': 41,
#     u'name': u'Out (Wood)',
#     u'uid': u'C616FB42-6F61-630A-E681-D170F84D1742'},
#    {u'importance': 31,
#     u'name': u'Up (Air)',
#     u'uid': u'C5EF7029-5E84-7F61-B2D1-97D8030F514C'},
#    {u'importance': 36,
#     u'name': u'dynamism',
#     u'uid': u'1E66C428-F242-7510-C474-303C768870F4'},
#    {u'importance': 47,
#     u'name': u'good vibrations',
#     u'uid': u'A03A702B-0EC4-300A-D18C-1542C9023315'},
#    {u'importance': 18,
#     u'name': u'rebellious',
#     u'uid': u'3CD8FE90-F6BC-B74E-6770-460A4C8DC5F4'},
#    {u'importance': 50,
#     u'name': u'energetic',
#     u'uid': u'2AD989FA-7E04-54B0-5ED8-924EE47604C0'},
#    {u'importance': 80,
#     u'name': u'impulsive',
#     u'uid': u'C5131D74-04FA-F960-16D8-49570FB115E5'},
#    {u'importance': 50,
#     u'name': u'desirable',
#     u'uid': u'78AB3FB8-D41B-9369-06A9-2FFC278F9DAB'},
#    {u'importance': 50,
#     u'name': u'driving',
#     u'uid': u'AFA2F319-53CC-EC1A-7F30-BF3B0F951AD8'},
#    {u'importance': 50,
#     u'name': u'nice',
#     u'uid': u'2B1D85F5-311E-C9FB-2595-170408E48556'},
#    {u'importance': 40,
#     u'name': u'summery',
#     u'uid': u'10B25425-2F30-F0C5-BFFA-EC729F7C9BD6'},
#    {u'importance': 25,
#     u'name': u'strong',
#     u'uid': u'FD1F84B8-9FBB-428D-6469-0C9FA70E5AA5'},
#    {u'importance': 100,
#     u'name': u'provocative',
#     u'uid': u'1239178A-A38F-AD13-0A21-689206A78F1E'},
#    {u'importance': 70,
#     u'name': u'absolute',
#     u'uid': u'515746E4-4781-D94D-D962-57924B6438FF'},
#    {u'importance': 75,
#     u'name': u'serene',
#     u'uid': u'3212CFA7-0B20-4EC4-CD3D-08E291F6620A'},
#    {u'importance': 75,
#     u'name': u'sublime',
#     u'uid': u'7AD88EA9-8191-E4C1-86AD-9AD66035AAE8'},
#    {u'importance': 75,
#     u'name': u'meditative',
#     u'uid': u'918D8945-7DE0-2D8E-6190-5171A28719DA'},
#    {u'importance': 75,
#     u'name': u'calm',
#     u'uid': u'24E39BD5-83BB-7663-ECAD-0AE8BA506987'},
#    {u'importance': 75,
#     u'name': u'unique',
#     u'uid': u'1F650C5F-3B9F-DA31-649E-C7CF36EAD35B'},
#    {u'importance': 75,
#     u'name': u'intuitive',
#     u'uid': u'3419CB61-7C05-DD3B-432E-98F2C463B403'},
#    {u'importance': 40,
#     u'name': u' circular',
#     u'uid': u'C5AFA786-A7F8-0AC3-1469-05800BA2537A'},
#    {u'importance': 27,
#     u'name': u'trance-like',
#     u'uid': u'423CF317-3707-3AAB-AADC-F97B40C26A46'},
#    {u'importance': 44,
#     u'name': u'organic',
#     u'uid': u'55BEDE8D-6CC4-0C4A-F362-15A8560151C8'},
#    {u'importance': 50,
#     u'name': u'relaxed',
#     u'uid': u'EB81AEF8-DF23-8F56-A5A9-33DE89C845CB'},
#    {u'importance': 33,
#     u'name': u'friendly',
#     u'uid': u'B0740C6D-7607-3999-9F6C-F66D5E268A50'},
#    {u'importance': 33,
#     u'name': u'healthy',
#     u'uid': u'ED52197F-AF23-4B72-B63E-EECD0B60FD47'},
#    {u'importance': 100,
#     u'name': u'hypnotic',
#     u'uid': u'083AE5B4-A1B7-CF1F-4701-F4F2C2CFF60B'},
#    {u'importance': 33,
#     u'name': u'round',
#     u'uid': u'F99048F4-BCB1-5C66-C27A-2B853BC76112'},
#    {u'importance': 50,
#     u'name': u'wavering',
#     u'uid': u'DC8328DD-5BC7-677B-F6B0-CFCAFFD4D69E'},
#    {u'importance': 75,
#     u'name': u'peaceful',
#     u'uid': u'5B2C527B-3B75-3F83-9636-5107B3AD96D9'},
#    {u'importance': 75,
#     u'name': u'soothing',
#     u'uid': u'4975732F-3C0C-2F7B-F7A9-7C31398B1569'},
#    {u'importance': 50,
#     u'name': u'caring',
#     u'uid': u'E7C1011A-063E-927F-2203-4CB236BEA20D'},
#    {u'importance': 27,
#     u'name': u'experimental',
#     u'uid': u'79859BD2-3DCC-3F81-2048-0F0897C04104'},
#    {u'importance': 27,
#     u'name': u'light',
#     u'uid': u'1E089F14-4FA3-839E-C702-1A371051F7E6'},
#    {u'importance': 33,
#     u'name': u'discreet',
#     u'uid': u'6BE29A1A-B01F-AD6A-7CA5-AF3AE60A1419'},
#    {u'importance': 50,
#     u'name': u'inhibited',
#     u'uid': u'BBBEB03B-DE97-EC0E-D6EC-94EF10DED278'},
#    {u'importance': 33,
#     u'name': u'austere',
#     u'uid': u'327BE7E4-B1F0-D3EE-016C-08C7D85F4F0F'},
#    {u'importance': 33,
#     u'name': u'deep',
#     u'uid': u'044BC3C6-9073-B7F4-E171-31F09E59FD73'},
#    {u'importance': 85,
#     u'name': u'intimate',
#     u'uid': u'A4592BA4-C56E-F654-8939-0772675E3919'},
#    {u'importance': 85,
#     u'name': u'mysterious',
#     u'uid': u'90E92479-7B16-3224-3D57-3074064EFC7A'},
#    {u'importance': 22,
#     u'name': u'obscure',
#     u'uid': u'7D5104F0-F92B-162F-544F-D6578F14E850'},
#    {u'importance': 25,
#     u'name': u'warm-hearted',
#     u'uid': u'13F575EB-9BD7-BC37-61A8-4E80DED7F1AD'},
#    {u'importance': 100,
#     u'name': u'atmospheric',
#     u'uid': u'B6DF5F89-E389-EFD3-2175-7EF6BE38FF43'},
#    {u'importance': 50,
#     u'name': u'ethereal',
#     u'uid': u'B8AAF601-F425-F663-327C-442BB68D995E'},
#    {u'importance': 50,
#     u'name': u'sensitive',
#     u'uid': u'5FCD7DCD-9C2C-F96D-1EE8-D9A3EF5886AB'},
#    {u'importance': 59,
#     u'name': u'emotional',
#     u'uid': u'5BC6DCE0-5979-2889-25B7-52C05CE2D721'},
#    {u'importance': 78,
#     u'name': u'thoughtful',
#     u'uid': u'446DDB2A-513B-0BDB-B2FD-6F25C401428A'},
#    {u'importance': 12,
#     u'name': u'odd',
#     u'uid': u'A424620A-6B62-5AE4-7201-AECD3BDD9BBB'},
#    {u'importance': 23,
#     u'name': u'daydreaming',
#     u'uid': u'F6BEBC77-7E49-421B-6485-6C27D9EB0E72'},
#    {u'importance': 100,
#     u'name': u'determined',
#     u'uid': u'0F009D11-53FD-52C7-FCF3-B12A853DA171'},
#    {u'importance': 100,
#     u'name': u'intense',
#     u'uid': u'88E4D296-5FD6-4A9E-C4E4-5E1DD302CB8B'},
#    {u'importance': 100,
#     u'name': u'cerebral',
#     u'uid': u'06CB5405-5031-9D8B-B099-9B6966AFDB6A'},
#    {u'importance': 50,
#     u'name': u'in your face',
#     u'uid': u'7D4A6714-A918-43F7-D1F5-96A1963DFC00'},
#    {u'importance': 100,
#     u'name': u'aggressive',
#     u'uid': u'9F0A9F9C-501D-F853-4376-AD2F9A856D1C'},
#    {u'importance': 90,
#     u'name': u'metallic',
#     u'uid': u'9B574DAE-6872-1F28-48B3-2C4FDC33AEA7'},
#    {u'importance': 50,
#     u'name': u'sanitized',
#     u'uid': u'BAFE4EDF-9FDD-0362-66B3-9AA6C6632BBB'},
#    {u'importance': 35,
#     u'name': u'clinical',
#     u'uid': u'C2FAA0CF-DC3C-2F74-2EA4-C87A4317E7E1'},
#    {u'importance': 80,
#     u'name': u'threatening',
#     u'uid': u'F6C5910A-03A8-EF23-F5B6-1AA0258C419D'},
#    {u'importance': 33,
#     u'name': u'sad',
#     u'uid': u'255CD3EC-C275-09A3-2682-9C8CB4BA375E'},
#    {u'importance': 77,
#     u'name': u'dull',
#     u'uid': u'541463D8-F4EB-E9F4-36EA-482B96DB6807'},
#    {u'importance': 18,
#     u'name': u'isolated',
#     u'uid': u'F7948819-E666-5D98-EB31-AACB6ABEEA9D'},
#    {u'importance': 88,
#     u'name': u'lightless',
#     u'uid': u'F89DEB79-525C-7DBF-A04C-44FC4833743B'},
#    {u'importance': 50,
#     u'name': u'introvert',
#     u'uid': u'6224027F-950C-0C12-BD5B-8541C8F2FDB1'},
#    {u'importance': 100,
#     u'name': u'monotonous',
#     u'uid': u'738D9847-E8D3-1103-62F3-544560487171'},
#    {u'importance': 17,
#     u'name': u'enigmatic',
#     u'uid': u'056281D8-8CE9-955C-3B57-75ECF50071B8'},
#    {u'importance': 80,
#     u'name': u'sinister',
#     u'uid': u'5E3783EF-4AB7-5B09-1666-DFBD953EA068'},
#    {u'importance': 100,
#     u'name': u'difficult',
#     u'uid': u'BD7BA5CE-1C02-ABE0-F767-58EA2B13E98B'},
#    {u'importance': 20,
#     u'name': u'complex',
#     u'uid': u'6F1D3063-E8E1-C3FF-48C4-FD8C81913DCA'},
#    {u'importance': 100,
#     u'name': u'fragile',
#     u'uid': u'30DF5DDC-46B1-3BD8-0D2D-DC0CC813624B'},
#    {u'importance': 100,
#     u'name': u'vulnerable',
#     u'uid': u'E0546129-DB97-6517-05E7-63C9720E2AE5'},
#    {u'importance': 50,
#     u'name': u'doubtful',
#     u'uid': u'F296867D-35E5-E26F-87BA-EFB02D6C9871'},
#    {u'importance': 88,
#     u'name': u'anxious',
#     u'uid': u'27FD4EE3-26D4-FB05-83F2-790E0F91D3F9'},
#    {u'importance': 88,
#     u'name': u'anxiety',
#     u'uid': u'213BBCF2-F9B1-5AE8-1440-3C8EFAEE7EAF'},
#    {u'importance': 88,
#     u'name': u'self-destructive',
#     u'uid': u'308A7A63-573F-3643-1B65-596B18F8A1B9'},
#    {u'importance': 50,
#     u'name': u'changing',
#     u'uid': u'F56B6D0A-C6D6-50A1-4150-389E59F67972'},
#    {u'importance': 50,
#     u'name': u'sparkling',
#     u'uid': u'E0B561D5-83DF-F347-D5B6-213CA348745A'},
#    {u'importance': 50,
#     u'name': u'vivacious',
#     u'uid': u'871BFE45-D885-93BF-9D08-669B102FA0F9'},
#    {u'importance': 20,
#     u'name': u'spring',
#     u'uid': u'3FF28522-10B9-0E07-484D-0E17D75DBB34'},
#    {u'importance': 10,
#     u'name': u'upset',
#     u'uid': u'78BCC1B7-FD5E-0031-3703-372B5E3482B0'}],
#   u'nickname': u'23 Skidoo',
#   u'score': 100,
#   u'uid': u'F54B72C3-D9C8-88DF-6ABE-348C175A6D80'},
#  {u'moods': [{u'importance': 47,
#     u'name': u'sensibility',
#     u'uid': u'6D5AE713-FA4A-2067-6CC8-B296D29EF57B'},
#    {u'importance': 33,
#     u'name': u'spontaneous',
#     u'uid': u'CF7D9EA4-6181-7C04-B025-75A9CFED953A'},
#    {u'importance': 88,
#     u'name': u'witty',
#     u'uid': u'61446A69-ECBF-0C45-D544-0B22F1DC65B0'},
#    {u'importance': 88,
#     u'name': u'spirited',
#     u'uid': u'D7D91543-9EF2-2965-D4CC-A7A44D86E442'},
#    {u'importance': 50,
#     u'name': u'communicative',
#     u'uid': u'E50384B0-7F88-3104-39A2-184147A58DE2'},
#    {u'importance': 50,
#     u'name': u'positive',
#     u'uid': u'10936331-149D-BFEA-F8EA-70CFE8B2836D'},
#    {u'importance': 66,
#     u'name': u'driving',
#     u'uid': u'AFA2F319-53CC-EC1A-7F30-BF3B0F951AD8'},
#    {u'importance': 22,
#     u'name': u'soft',
#     u'uid': u'A10C9421-7F41-1C06-268E-2E921D877595'},
#    {u'importance': 22,
#     u'name': u'bitter',
#     u'uid': u'920A2CCD-7C51-B3FF-56A8-B056208C4498'},
#    {u'importance': 100,
#     u'name': u'bittersweet',
#     u'uid': u'62482C44-67CE-6A87-BC39-B6D15D6CF153'},
#    {u'importance': 50,
#     u'name': u'dreaming',
#     u'uid': u'3950E503-C4C9-5776-816D-EE3959AB6AE4'},
#    {u'importance': 100,
#     u'name': u'intense',
#     u'uid': u'88E4D296-5FD6-4A9E-C4E4-5E1DD302CB8B'},
#    {u'importance': 100,
#     u'name': u'daydreaming',
#     u'uid': u'F6BEBC77-7E49-421B-6485-6C27D9EB0E72'},
#    {u'importance': 100,
#     u'name': u'bravado',
#     u'uid': u'5E579C46-BD0F-D09B-1B52-498CAE52A095'},
#    {u'importance': 23,
#     u'name': u'brave',
#     u'uid': u'9A617502-7C7B-2478-F110-CFE191A1BDD2'},
#    {u'importance': 10,
#     u'name': u'heroic',
#     u'uid': u'EFE2C415-2781-B731-1AD1-FEEDD20B370A'},
#    {u'importance': 58,
#     u'name': u'loud',
#     u'uid': u'F14B73B9-C320-B6E1-0911-CC6D7837D8F5'},
#    {u'importance': 10,
#     u'name': u'pretty',
#     u'uid': u'6CEBAF4C-A524-2EF9-9061-6B5CA6490EA3'},
#    {u'importance': 10,
#     u'name': u'aesthetic',
#     u'uid': u'86712840-0F9C-3AA0-74C5-DFBA82E879D1'},
#    {u'importance': 88,
#     u'name': u'refined',
#     u'uid': u'80B02A5D-3853-D70D-7336-8E3CC5CB5457'},
#    {u'importance': 33,
#     u'name': u'desirable',
#     u'uid': u'78AB3FB8-D41B-9369-06A9-2FFC278F9DAB'},
#    {u'importance': 33,
#     u'name': u'pretentious',
#     u'uid': u'0599F73B-6A25-E9DA-4668-589A71739A73'},
#    {u'importance': 22,
#     u'name': u'bright',
#     u'uid': u'04EAD4A4-2A90-BC36-579D-408F47E4F0AC'},
#    {u'importance': 88,
#     u'name': u'disconsolate',
#     u'uid': u'C1DA3F70-3D54-D0B4-102E-C99F21781EE2'},
#    {u'importance': 50,
#     u'name': u'caring',
#     u'uid': u'E7C1011A-063E-927F-2203-4CB236BEA20D'},
#    {u'importance': 100,
#     u'name': u'atmospheric',
#     u'uid': u'B6DF5F89-E389-EFD3-2175-7EF6BE38FF43'},
#    {u'importance': 80,
#     u'name': u'threatening',
#     u'uid': u'F6C5910A-03A8-EF23-F5B6-1AA0258C419D'},
#    {u'importance': 80,
#     u'name': u'sinister',
#     u'uid': u'5E3783EF-4AB7-5B09-1666-DFBD953EA068'},
#    {u'importance': 33,
#     u'name': u'deep',
#     u'uid': u'044BC3C6-9073-B7F4-E171-31F09E59FD73'},
#    {u'importance': 44,
#     u'name': u'determined',
#     u'uid': u'0F009D11-53FD-52C7-FCF3-B12A853DA171'},
#    {u'importance': 33,
#     u'name': u'flashy',
#     u'uid': u'B45AD70C-F647-D61D-7542-072AFDE3A526'},
#    {u'importance': 100,
#     u'name': u'melodramatic',
#     u'uid': u'EBD72BDD-08AC-1AF2-B72F-DA30FF41730F'},
#    {u'importance': 58,
#     u'name': u'proud',
#     u'uid': u'458E616F-1B47-310F-755B-CA07EA19E8B6'},
#    {u'importance': 12,
#     u'name': u'exaggerated',
#     u'uid': u'6DCC7FFC-A6D0-8352-8198-97448BCEDF7D'},
#    {u'importance': 17,
#     u'name': u'mannered',
#     u'uid': u'39ACA5F9-01D8-57AA-1E6F-CE6ACF27B6DA'},
#    {u'importance': 78,
#     u'name': u'ambitious',
#     u'uid': u'6933A010-6D30-A84F-BD02-0B5F385C2B26'},
#    {u'importance': 99,
#     u'name': u'introvert',
#     u'uid': u'6224027F-950C-0C12-BD5B-8541C8F2FDB1'},
#    {u'importance': 100,
#     u'name': u'isolated',
#     u'uid': u'F7948819-E666-5D98-EB31-AACB6ABEEA9D'},
#    {u'importance': 100,
#     u'name': u'fragile',
#     u'uid': u'30DF5DDC-46B1-3BD8-0D2D-DC0CC813624B'},
#    {u'importance': 100,
#     u'name': u'vulnerable',
#     u'uid': u'E0546129-DB97-6517-05E7-63C9720E2AE5'},
#    {u'importance': 100,
#     u'name': u'melancholic',
#     u'uid': u'DD640E4F-94C6-57B3-E373-2D68E5F90CFC'},
#    {u'importance': 50,
#     u'name': u'doubtful',
#     u'uid': u'F296867D-35E5-E26F-87BA-EFB02D6C9871'},
#    {u'importance': 88,
#     u'name': u'anxious',
#     u'uid': u'27FD4EE3-26D4-FB05-83F2-790E0F91D3F9'},
#    {u'importance': 88,
#     u'name': u'self-destructive',
#     u'uid': u'308A7A63-573F-3643-1B65-596B18F8A1B9'},
#    {u'importance': 100,
#     u'name': u'extravagant',
#     u'uid': u'412E2463-7085-1C4E-B601-B74286465235'},
#    {u'importance': 33,
#     u'name': u'monotonous',
#     u'uid': u'738D9847-E8D3-1103-62F3-544560487171'},
#    {u'importance': 88,
#     u'name': u'anxiety',
#     u'uid': u'213BBCF2-F9B1-5AE8-1440-3C8EFAEE7EAF'},
#    {u'importance': 100,
#     u'name': u'nostalgic',
#     u'uid': u'FC883530-E528-6A79-B963-B903ADD9FC29'},
#    {u'importance': 100,
#     u'name': u'sentimental',
#     u'uid': u'104AC159-974B-14CE-7A73-63D91126F4F9'},
#    {u'importance': 100,
#     u'name': u'autumnal',
#     u'uid': u'A15DDD60-8379-2972-6DFF-610FDC2343E6'},
#    {u'importance': 100,
#     u'name': u'romantic',
#     u'uid': u'9FCC01A9-1AE4-18BD-B5AE-6CD1C7A1D09E'}],
#   u'nickname': u'Harry Gregson-Williams',
#   u'score': 100,
#   u'uid': u'E8C8803C-B2E9-E993-7B77-CF53A12E7AC8'}]

# %%
params
# Out:
# {'access_token': u'6Lgd2ytvO76jnj4Fz19JHEwYUFdbzELwyK7nS4dW',
#  'moods[0][importance]': 50,
#  'moods[0][uid]': u'E7C1011A-063E-927F-2203-4CB236BEA20D',
#  'output': 'moods'}

# %% [markdown]
# ## Album Search

# %% [markdown]
# ### Get  random albums:

# %%
call = 'albums/search' 

output = 'owners,keywords'
#output = 'references'

params = {'limit': 5, 'output': output, 'access_token': token}  # limit: default 10, max. 50

#resp = requests.get(base + call, headers=headers)  # without limit
resp = requests.get(base + call, params, headers=headers) # with limit
resp.status_code
# Out:
# 200

# %%
json = resp.json()
results = json['results']
results
# Out:
# [{u'keywords': [],
#   u'name': u'So Much Guitar ! 1961 (Original Jazz Sound)',
#   u'owners': [{u'nickname': u'Wes Montgomery',
#     u'uid': u'557CE494-19D5-6B16-766C-6CF68ADCD804'}],
#   u'score': 100,
#   u'uid': u'6B042DDA-7B6F-159C-8278-597C52ACF21D'},
#  {u'keywords': [],
#   u'name': u'The Featurings (P4rt I)',
#   u'owners': [{u'nickname': u'Qlub 4ntz',
#     u'uid': u'FD4B3B89-7561-A2BA-C5EB-7775A2033D30'}],
#   u'score': 100,
#   u'uid': u'0D0A14B0-3E07-C9AF-4577-EEBF3FC42E34'},
#  {u'keywords': [],
#   u'name': u'J. S. Bach: Die Kunst der Fuge',
#   u'owners': [{u'nickname': u'Keller Quartett',
#     u'uid': u'726CB783-5FFF-DA3D-EC53-BD5B74E9C128'}],
#   u'score': 100,
#   u'uid': u'81781D1A-6574-31EB-2096-F202B0831DF6'},
#  {u'keywords': [],
#   u'name': u'Music of London',
#   u'owners': [{u'nickname': u'London Philharmonic Orchestra',
#     u'uid': u'DCD71514-E49C-51FC-16EC-A731B0B66EEC'}],
#   u'score': 100,
#   u'uid': u'404B6C90-B75F-EC70-92C9-6F2625FC7DD4'},
#  {u'keywords': [],
#   u'name': u"Bleib' sauber!",
#   u'owners': [{u'nickname': u'Anselm Tripptrap',
#     u'uid': u'8C5022BE-B5F1-89B3-F683-D2CE542574DB'},
#    {u'nickname': u'The Strutters',
#     u'uid': u'98A35745-E25B-A12A-4C38-1E708B60B83C'}],
#   u'score': 100,
#   u'uid': u'70393288-AC89-4B78-ED98-F950E7EFC6E7'}]

# %%
for album in results:
    artist = album['owners'][0] # get the 1st artist in list
    keywords = album['keywords']
    keywords = ",".join([k['name'] for k in keywords])
    print(album['name'], '-', artist['nickname'], ':\t', keywords)
# Out:
# So Much Guitar ! 1961 (Original Jazz Sound) - Wes Montgomery :
# The Featurings (P4rt I) - Qlub 4ntz :
# J. S. Bach: Die Kunst der Fuge - Keller Quartett :
# Music of London - London Philharmonic Orchestra :
# Bleib' sauber! - Anselm Tripptrap :

# %% [markdown]
# ### Search for specific Album:

# %%
call = 'albums/search' 

album = 'coldplay'
#album = 'lamb'
#album = 'thriller' # 500

params = {'name': album, 'access_token': token} 

resp = requests.get(base + call, params, headers=headers) 
resp.status_code
# Out:
# 200

# %%
json = resp.json()
results = json['results']

for r in results:
    print(r['score'], r['uid'], r['name'])
# Out:
# 100 E42F6A3A-A031-5103-F75F-632CB968B382 Baby Deli - Coldplay
# 80.43 E6C9C37B-D277-FBD2-456C-F51CA86FC613 Atlas: Tribute To Coldplay
# 80.43 B701199A-2AE5-1399-822E-C6545B534240 Atlas: Tribute to Coldplay
# 80.24 0BAB4C44-2BAE-72EB-855C-97AEEE7542F0 Piano Tribute to Coldplay, Vol. 2
# 79.84 400FDE39-2F9D-72A7-807A-A0972FE00A3E Symphonic Coldplay
# 79.84 C81D2AA7-D197-BED9-9B63-CC8FB7048057 A Metal Tribute To Coldplay
# 79.84 F884A8CF-A83D-AC9C-E72F-4FCA3B596699 Coldplay Piano Tribute
# 79.84 F57D4638-C987-54BA-C61F-017AF53B8808 Hands On Coldplay By Tiny Thomas
# 79.84 06F8E1CD-7B08-1FA6-FEE9-449E091499EE Coldplay, Elvis & John Cage
# 79.84 1E8CED6B-B789-1864-4667-BFD5BF010028 Tribute to Coldplay

# %% [markdown]
# ### Get Specific Album's Details by IDs from Musimap, Spotify, Discogs, etc.

# %%
call = 'albums/search'

# %%
# a) by Musimap ID
#album_id = 'BB3ECAB3-6522-9A5E-F5D0-4A425A9460C3' # from earlier query above
album_id = 'E42F6A3A-A031-5103-F75F-632CB968B38' # from earlier query above
params = {'reference': album_id, 'access_token': token} 

resp = requests.get(base + call, params, headers=headers) 
resp.status_code
# Out:
# 200

# %%
# b) by Discogs ID
discogs_id = '3704040'
params = {'reference': discogs_id, 'reference_provider': 'Discogs', 'access_token': token}

resp = requests.get(base + call, params, headers=headers) 
resp.status_code
# Out:
# 200

# %%
# c) by Spotify ID
spotify_id = '1AHKJJbdFuzlbpQgiokyw7 '
params = {'reference': spotify_id, 'reference_provider': 'Spotify', 'access_token': token}

resp = requests.get(base + call, params, headers=headers) 
resp.status_code
# Out:
# 200

# %%
resp.text
# Out:
# u'{"total":0,"limit":10,"offset":0,"results":[]}'

# %% [markdown]
# ## Album Details - not in v 2.0
#
# Get details about above artist's album's:

# %%
results['discography']
# Out:
# [{u'genre': {u'name': u'Alternative Folk soul / Pop ',
#    u'uid': u'C96C3138-29BC-0E3C-775B-F6B39CE31219'},
#   u'name': u'Speed',
#   u'uid': u'9CA940F2-97A3-8D86-619C-72722BA3459B',
#   u'year': u'201111'}]

# %%
album = results['discography'][0]

# %%
album['uid']
# Out:
# u'9CA940F2-97A3-8D86-619C-72722BA3459B'

# %%
call = 'album/' + album['uid']

# output parameter controls the result and is one of the following:
# details, properties, moods, influences, owners, releases
# (can be combined in comma-separated way)

params = {'output': 'details,owners,moods', 'access_token': token}

resp = requests.get(base + call, params)
#resp.status_code
json = resp.json()
results = json['results']
results
# Out:
# {u'details': {u'genre': {u'name': u'Alternative Folk soul / Pop ',
#    u'uid': u'C96C3138-29BC-0E3C-775B-F6B39CE31219'},
#   u'subtitle': u'',
#   u'year': u'201111'},
#  u'last_update': 1419416996,
#  u'moods': [],
#  u'name': u'Speed',
#  u'owners': [{u'nickname': u'Nylon Hotel',
#    u'uid': u'67F9424C-22D9-99FA-BC75-921B7B3A7309'}],
#  u'score_expertise': 55,
#  u'uid': u'9CA940F2-97A3-8D86-619C-72722BA3459B'}

# %% [markdown]
# ## Track Search
#
# List arbitrary tracks from database: (`limit` and `offset` allow pagination):

# %%
call = 'tracks/search'
params = {'limit': 8, 'offset': 0, 'output': 'owners', 'access_token': token}

resp = requests.get(base + call, params, headers=headers)
resp.status_code

json = resp.json()
results = json['results']
results
# Out:
# [{u'name': u'Oyeh!',
#   u'owners': [{u'nickname': u'Dr. Feelgood',
#     u'uid': u'55DAA270-69B5-124C-8039-A88ADAF07BD6'}],
#   u'score': 100,
#   u'uid': u'9C34548B-FFE7-49B5-DA3D-CB07A588F178'},
#  {u'name': u'Raga Megh malhan',
#   u'owners': [{u'nickname': u'Amjad Ali Khan',
#     u'uid': u'10316894-5DD9-A873-6FF4-5C6006333E53'}],
#   u'score': 100,
#   u'uid': u'A9936240-F7EB-1CCC-67A6-BBE29CBD59C9'},
#  {u'name': u'Introspection (take 1)',
#   u'owners': [{u'nickname': u'Thelonious Monk',
#     u'uid': u'13371644-2D14-C4F3-EDB6-56F1C48187DD'}],
#   u'score': 100,
#   u'uid': u'64B1E494-8611-78F8-B321-13417339FD59'},
#  {u'name': u'La f\xe9e verte',
#   u'owners': [{u'nickname': u'Adolphe Berard',
#     u'uid': u'C72B760D-D5DA-6AC6-0AAC-00C9360227D0'}],
#   u'score': 100,
#   u'uid': u'190056B1-D18F-913B-5B76-D24AA65899EF'},
#  {u'name': u'Save Me',
#   u'owners': [{u'nickname': u'Silver Convention',
#     u'uid': u'643B0F88-CDE0-689F-C518-CA7E7C6A3CDE'}],
#   u'score': 100,
#   u'uid': u'53137908-DB91-97D3-9FAE-90770160B20B'},
#  {u'name': u'One Weekend',
#   u'owners': [{u'nickname': u'Dr. Feelgood',
#     u'uid': u'55DAA270-69B5-124C-8039-A88ADAF07BD6'}],
#   u'score': 100,
#   u'uid': u'37BF6FEF-4685-EF3D-0BAA-3256FD0BF933'},
#  {u'name': u'Panamena',
#   u'owners': [{u'nickname': u'Willie Colon',
#     u'uid': u'CEE5D037-B16D-0B94-3C79-1885352C9C20'}],
#   u'score': 100,
#   u'uid': u'5AB43ABF-A50E-9B7A-0A2B-9C96D39A50AD'},
#  {u'name': u'Evidence',
#   u'owners': [{u'nickname': u'Thelonious Monk',
#     u'uid': u'13371644-2D14-C4F3-EDB6-56F1C48187DD'}],
#   u'score': 100,
#   u'uid': u'104CF2D7-ED92-BA6B-E9B6-9CD1A241B140'}]

# %%
for track in results:
    print(track['name'], "-", track['owners'][0]['nickname'])  # note: owners (artists) is a list, we take the 1st one
# Out:
# Oyeh! - Dr. Feelgood
# Raga Megh malhan - Amjad Ali Khan
# Introspection (take 1) - Thelonious Monk
# La fée verte - Adolphe Berard
# Save Me - Silver Convention
# One Weekend - Dr. Feelgood
# Panamena - Willie Colon
# Evidence - Thelonious Monk

# %% [markdown]
# ### Track Search by String Match

# %%
call = 'tracks/search'

track = 'Hello'

#params = {'name': track} # confusing result, where scores do not make much sense
params = {'title': track, 'limit': 10, 'output': 'owners', 'access_token': token} # different, more exact result

resp = requests.get(base + call, params, headers=headers)
resp.status_code
# Out:
# 200

# %%
json = resp.json()
results = json['results']

for track in results:
    if len(track['owners']) > 0:
         # note: owners (artists) is a list, we take the 1st one
        artist = track['owners'][0]['nickname']
    else:
        artist = ''
    print(track['name'], "-", artist)
# Out:
# Hello - Phil Perry
# Hello - Maaya Sakamoto
# Hello - The Nutmegs
# Hello - Cécile Charbonnel
# Hello -
# Hello - Uwe Hell
# Hello - Omara
# Hello -
# Hello - S.N.O.P.
# Hello - Spacekid

# %% [markdown]
# ### Track Search from certain Artist

# %%
call = 'tracks/search'

track = 'Hello'
artist = 'D1800E01-04B0-F9D3-91CA-CAC4954717E8' # = 'Adele' # needs to be UID

#params = {'name': track, 'owner':artist, 'access_token': token}
params = {'title': track, 'owner':artist, 'access_token': token} # optional: 'output':'owners'

resp = requests.get(base + call, params, headers=headers)
resp.status_code
# Out:
# 200

# %%
resp.text
# Out:
# u'{"total":229,"limit":10,"offset":0,"results":[{"uid":"13AE63C3-18C2-ED86-25D1-3794AAD0EB4D","name":"Hello","score":100},{"uid":"0103CD09-50BF-4163-9808-90AD590E34D0","name":"Hello (The Voice Mix)","score":61.23},{"uid":"3A6C332A-517C-8F06-8AAF-DF8B073217CF","name":"Hello (Single)","score":60.02},{"uid":"853706C8-16FB-42E3-6C3B-5D8813A3B81B","name":"Hello (Radio Remix)","score":50},{"uid":"3718D179-DF0C-B4F9-A5BC-BB9089E02262","name":"Hello 2016 (Radio Remix from the Other Side)","score":41.52},{"uid":"D1DEBBA2-0B96-E8C8-EC98-57C133923229","name":"Hello (Workout Gym Mix 140 BPM)","score":39.98},{"uid":"1521A33D-B1CC-51C2-0521-2B506FBAE2B1","name":"Hello (Extended Voice Mix)","score":39.98},{"uid":"5AF4662B-E931-033A-17C7-670A8C0337EF","name":"Hello (Extended Mashup Club Mix)","score":39.98},{"uid":"EBE4BD81-87AD-A438-21DA-B18C83247FA0","name":"Hello 2016 (Vocal Acapella Vocals Mix)","score":38.11},{"uid":"352AB589-0436-1C37-CD20-CE342A4E9A25","name":"Hello (Acapella Vocals Voice Mix)","score":38.11}]}'

# %%
json = resp.json()
results = json['results']

for track in results:
    print(track['name'])
# Out:
# Hello
# Hello (The Voice Mix)
# Hello (Single)
# Hello (Radio Remix)
# Hello 2016 (Radio Remix from the Other Side)
# Hello (Workout Gym Mix 140 BPM)
# Hello (Extended Voice Mix)
# Hello (Extended Mashup Club Mix)
# Hello 2016 (Vocal Acapella Vocals Mix)
# Hello (Acapella Vocals Voice Mix)

# %% [markdown]
# ### Track Search by Genre

# %%
# UID for "indie rock" see Genre search above
uid = '9A620E39-2784-2E3A-1DF0-4743DBC26139'

# all genres, moods etc. have an importance value in %
# we specify here that the genre value must have at least 45% for the tracks we want
importance_min = 45

# for specifiyng a range, ":" is used; "45:" means minimum 45% (>= 45%)
importance_str = str(importance_min) + ':'

# %%
call = 'tracks/search'

params = {'influences[0][type]': 'genre', 
          'influences[0][uid]': uid,
          'influences[0][importance]': importance_str} 
           # optional: 'output':'owners'

resp = requests.get(base + call, params, headers=headers)
resp.status_code
# Out:
# 200

# %%
if resp.status_code != 200:
    raise ValueError("Response Code was:", resp.status_code)

json = resp.json()
results = json['results']
results
# Out:
# [{u'name': u'Friction',
#   u'score': 0,
#   u'uid': u'D0C529B7-508E-358E-568A-3525FC3284F7'},
#  {u'name': u'The Mercy Seat',
#   u'score': 0,
#   u'uid': u'4C952D16-19E1-6CB3-AF98-CB674632C231'},
#  {u'name': u"13'40_5 10",
#   u'score': 0,
#   u'uid': u'A30B5DE7-F34E-BF17-4184-CE2CB0140159'},
#  {u'name': u'Pass Like Night',
#   u'score': 0,
#   u'uid': u'4E238133-A84F-0939-6D5E-5001AE09D9A7'},
#  {u'name': u'Pars',
#   u'score': 0,
#   u'uid': u'AE5AD173-CDA1-C78E-70AD-BB00E0EF8F4F'},
#  {u'name': u'Coin De Rue',
#   u'score': 0,
#   u'uid': u'29793500-70E7-E652-5E39-3227FC7C76D6'},
#  {u'name': u'This Time of Night',
#   u'score': 0,
#   u'uid': u'DA88D067-307C-EA88-E8A4-6E3D2247DC58'},
#  {u'name': u'The Perfect Kiss',
#   u'score': 0,
#   u'uid': u'7427D78E-EA46-C128-BDFB-294F2192D1F7'},
#  {u'name': u'I Can Hear Her Fighting with Herself',
#   u'score': 0,
#   u'uid': u'75C8E904-EE15-9986-DD1A-6FA1EF8B1668'},
#  {u'name': u'The Lonely Little Thrift Store',
#   u'score': 0,
#   u'uid': u'236489B7-0886-FA61-245B-B6B2E5903EF1'}]

# %% [markdown]
# You may use the UIDs from the track search result to query for more details about the track. See below.

# %% [markdown]
# ## Track Details
#
# ### Keywords, Moods, Instruments, BPM, Duration ...

# %%
# we take the track UID of the song "The Creation" found above

call = 'tracks/search'

track_uid = '97F27D19-91FF-460D-48BF-3A62D379EEDB'
#track_uid = 'B180FDAF-1F99-0CD2-8068-BCB97DAA0C6A'

# output parameter controls the result and is one of the following:
# details, properties, album, moods, influences, references
# (can be combined in comma-separated way)

#params = {'reference': track_uid, 'output': 'properties', 'access_token': token}
params = {'reference': track_uid, 'output': 'details,properties,album,moods,influences,references', 'access_token': token}


resp = requests.get(base + call, params, headers=headers)

if resp.status_code != 200:
    raise ValueError("Response Code was:", resp.status_code)

json = resp.json()
results = json['results']
results
# Out:
# [{u'album': {u'name': u'Paul Baker Presents The Speak Four Trio',
#    u'uid': u'314812D6-CA5B-3EAA-B100-EB1291B36D77'},
#   u'best_of_jury': False,
#   u'bonus': False,
#   u'bpm': 117,
#   u'duration': None,
#   u'hidden': False,
#   u'hit_parade': False,
#   u'index': u'2/B1',
#   u'influences': [],
#   u'instrumental': False,
#   u'live': False,
#   u'moods': [],
#   u'name': u'The Creation',
#   u'properties': [],
#   u'references': [],
#   u'score': 100,
#   u'uid': u'97F27D19-91FF-460D-48BF-3A62D379EEDB',
#   u'unrecorded': False,
#   u'year': u'00/1850'}]

# %%
for track in results:
    print (track['name'] + ':', track['bpm'], 'bpm')
# Out:
# The Creation: 117 bpm

# %% [markdown]
# ## Track Recommendation
#
# Get recommendations for similar tracks (based on a track):

# %%
# we take the track UID of the song "The Creation" found above

track_uid = '97F27D19-91FF-460D-48BF-3A62D379EEDB' # The Creation # 504 error
#track_uid = '15B46D07-726D-19E0-2A85-8C3311EBA872' # Boy King

call = 'tracks/' + track_uid + '/recommendations'

params = {'limit': 7, 'access_token': token}  # default 10, max. 50
# 'output': 'moods', -> NOT POSSIBLE IN THIS ENDPOINT

resp = requests.get(base + call, params, headers=headers) 
resp.status_code
# Out:
# 200

# %%
json = resp.json()
results = json['results']

print("SIMILAR TRACKS TO:",track_uid)

for track in results:
    print(track["score"], track["uid"], track["name"])
# Out:
# SIMILAR TRACKS TO: 97F27D19-91FF-460D-48BF-3A62D379EEDB
# 100 7BBA038A-902F-FD87-5EDD-9257B4310C7C A Soldier
# 100 BBCE7CCB-5E3D-0CA0-DA6D-11C983D282B0 Diskussion
# 100 AC120BBA-B90D-753C-6DBD-E3B0DE840094 Love Without Hope, What Did I Dream?, The Hills Of May, Angry Sansom, In Procession
# 100 97F27D19-91FF-460D-48BF-3A62D379EEDB The Creation
# 100 FC615F73-B680-CFBB-6D14-A6B21EE90331 Rigorists
# 100 02F09C3E-AC66-1F35-F127-9EA1531F0CEA Chorus, Messenger, Eurydice, Creon; Lines 1115-1125, 1155-1249, 1251-1269, 1277-1300, 1339-1353
# 100 B4B39E94-61BD-29AD-D650-423EB24B3C50 Chorus, Creon, Haemon; Lines 582-593, 626-644, 672-700, 724-780
# 100 561CC8A0-65C8-0C46-F9D6-3BAF60A30F32 O By The By (One Times One)
# 100 237C1102-3BBA-AD9C-0CD0-1C64D5A6F4DC Hanni Und Nanni Gründen Einen Klub (1)
# 100 A0EF94B0-C64D-91B9-847D-70412A736A95 The Canticle Of The Rose
# 100 9CA37ECC-AD90-B4CC-694E-583C9BEDF709 Hare Krsna Mantra
# 100 3910463D-9EEA-82E4-C6A9-97EC906C4DED Who Were So Dark Of Heart They Might Not Speak (XAIPE)
# 100 B5CC048A-033D-24B6-29AE-EF7D453FBB3B Hanni Und Nanni Groß In Form (2)
# 100 C2626EF8-92DB-45AB-09FF-A69812A1C26F Die Einsame Radfahrerin
# 100 2BF416E3-72CB-8A52-C151-FEB280F6099E What Are Years
# 100 CE75F4B7-2DDC-6D6E-CBDA-0F437FDF529D Le Paquet Rouge
# 100 166D1434-634F-BCD7-B9DC-237F679735FC There's A Place
# 100 69116A1F-CB40-DFA1-DDA3-6DD150A58E0B Song Of Queen Anne Boleyn: At Cockcrow
# 100 3C967890-287C-C5FD-1CA8-29433C7C7FF2 The Glorious Mysteries
# 100 466E3F7F-ED9F-2545-5764-615BD462ADA8 Antigone, Ismene; Lines 1-99
# 100 098B1121-1D60-279D-0A2E-3B879A2AFC55 Der Blaue Karfunkel Oder Die Weihnachtsgans
# 100 ACCDA81D-DF1E-AE7E-2C99-FE9E1629C2FE -
# 100 E4FCE264-ADEF-D5F2-1EF0-CE44DBEC1F4F Papagei
# 100 5D80170D-876B-41F1-1D74-29229E5D55EF The Wind's Bastinado
# 99.92 235851A7-FC13-1F8D-60AE-3A41C09D8A1E Payoff Met Instruments
# 99.84 766C0909-6782-E39C-F7C3-3249E4942ECF Nummer 1 In De Mega Top 100
# 99.84 FE6B4EB5-D50F-7224-089D-7289F54E483D Nummer 4 In De Mega Top 100
# 99.84 1E23D107-D6EC-F785-D1E7-6308A0237E9B Nummer 8 In De Mega Top 100
# 99.37 E077F1D5-78FF-E0C4-CA3E-A1B270603D7E "Now Let Me Tell You..."
# 99.33 ECBEBD88-064E-9BE7-FDF4-4C09B1F08CDB "Antigone, You See Her"
# 99.3 FFE6EA29-00BC-EF1C-1590-4C1D1A210994 Prayer Of The Holy Father And Blessing Hail Holy Queen
# 99.24 40F585E0-B5F7-10A1-96F6-E71A420E8C4C "Jazz"
# 99.12 FC9849E0-4119-6F5E-932C-BB4E9E039862 Rondloper ID Met Zakker Lang/Kort Editable
# 98.81 A06FBF6C-D575-62DC-B26A-C13BE2029978 The Family Garland
# 98.57 9C754E3A-0058-C2B4-5C71-7256ED828033 Pina Colada Song
# 98.45 AD7946DD-BE18-D272-5196-963E063B1E4C Untitled
# 98.22 E2F26A55-AA1A-FA39-595F-45965DFCAAD5 Opening Hymn And Prologue
# 98.12 0346991F-5A32-EA26-B4D6-BB5F8D7BCA6E Der Schwarm (Teil 12)
# 98.12 6BC6A2A8-A195-705E-AA7F-3C62C8B80A67 Ladies And Gentlemen We Are Floating In Space
# 98.04 712B8346-8DF0-A2CF-08CE-D58A21CEB4FF 1st Sorrowful Mystery: The Agony In The Garden
# 98.04 B06E994C-F4E9-23BD-9143-31FEFB218278 Untitled
# 98.04 632E5696-AF1B-C335-2C47-FB786A1914D2 4th Joyful Mystery: The Presentation
# 98.04 6AA0F92A-9E97-C13F-0390-A13E10B5C7F2 2nd Glorious Mystery: The Ascension
# 98.04 2AE19CFD-5D25-6C6E-8FE4-764C4B995C2E Captured By Pirates
# 98.04 18940332-1FBA-028A-F64A-8660C0F0CB65 3rd Mystery: The Crowning With Thorns
# 98.04 4A2078E6-48D5-28EE-22FF-43A55F45723E Der Schwarm (Teil 171)
# 98.04 8A247ED1-1224-8985-E215-70401A845222 Der Schwarm (Teil 173)
# 98.04 BC21FC02-E821-D1B7-98AE-813D5EE0B91A The Paris Match
# 98.04 F5552835-F82C-B925-A571-EC5F567E3402 Der Schwarm (Teil 50)
# 98.04 31212C72-41C6-0357-A956-C8AB01101199 Der Schwarm (Teil 4)
# 98.04 8628A35C-9979-F26C-D7DE-0034A7A6C325 Kiss Me Quick
# 98.04 A88C7AAE-50BA-7631-6BA9-D37BA4673AC8 Release Me
# 98.04 E826FE6A-2E96-7E04-CAEC-EFAA821E87B5 The Song Of The Dogs
# 98.04 D940978D-2E29-68EC-9FA6-C9A891F5D5D6 1st Mystery: The Annunciation
# 98.04 D2EEF70B-9C71-C97C-ED8C-50AEC18B6C57 Der Schwarm (Teil 148)
# 98.04 9E1404EA-CC29-B5BB-14E6-FB5E188B7078 Untitled
# 98.04 708582E5-CCA6-2EE4-64F1-FFEF44F8CD5E Der Schwarm (Teil 121)
# 98.04 E25DE430-5C3C-BCEA-08B7-876931AB4732 Der Schwarm (Teil 181)
# 98.04 868D5398-0ED9-9A68-1947-97DEB3D8EEA0 Total Eclipse Of The Heart
# 98.04 90E533C8-D57D-C87F-6961-1BD5AEDC32BF Der Schwarm (Teil 21)
# 98.04 E44AE8C5-547D-795A-B9D2-D62A66801A78 Der Schwarm (Teil 51)
# 98.04 DDB29AEA-3121-1124-0A61-FADAF9F35ED3 Untitled
# 98.04 627DC4B0-BE94-8C0F-18AB-50518AAE2CF3 Am Morgen Des Zweiten Weihnachtstages...
# 98.04 8B9122BC-F4E7-BE34-3A03-29F9E3E78CCC Untitled
# 98.04 B147C2D9-668A-2775-675B-838E667DD178 3rd Joyful Mystery: The Nativity
# 98.04 F898AE61-679E-B716-11E3-E7CC6A49A8D8 Untitled
# 98.04 3A60A66F-862E-CF6E-B6D1-EDDD53A82C89 "Opening Remarks"
# 98.04 E3B0A78B-7B41-BD0A-0465-E565596EB5BB 5th Joyful Mystery: The Finding In The Temple
# 98.04 C805F566-81E1-F521-C79C-9E90E4F2ED60 Note To Self: Don't Die / Flamingo / When Doves Cry
# 98.04 1FC8A9A8-1FC5-6A89-4134-BE99B2D25233 Der Schwarm (Teil 41)
# 98.04 961D64F8-7A8B-492B-5F0B-06B744FA6209 Juggler Turn Around
# 98.04 BC4AF946-DC53-FC55-154C-8A9A677F7344 Der Schwarm (Teil 20)
# 98.04 16CE81C0-F057-DBD7-BA97-4899817AC525 "Einen Augenblick, Bitte!"
# 98.04 D26A2ADE-9120-F17D-8574-B24B40E8699C 5th Glorious Mystery: The Coronation Of The Virgin Mary
# 98.04 F2CDC195-E8D3-970E-9E90-52B9FCB96D03 Der Schwarm (Teil 2)
# 98.04 25347D1B-EE8D-99AF-4F2A-88ED7F9BC45A Der Schwarm (Teil 82)
# 98.04 6EE64FBD-8291-B601-ABDC-7DEF0F86FDD8 Those Were The Days
# 98.04 A04C4445-B108-8188-3289-641CD39528BE Take My Hand Precious Lord
# 98.04 78E9AA12-6C23-1DCA-5C6F-30A2A1907041 Untitled
# 98.04 14C913FD-220E-BC81-D7EE-6101F5FE6DE3 Untitled
# 98.04 C5C95B2D-347E-F610-0567-5DC7E50470B9 Der Schwarm (Teil 161)
# 98.04 F9CCBF22-5A4C-343C-C9B0-C0FFB7961881 Little Cabin Home On The Hill
# 98.04 67A930D8-E1AD-9740-ED3C-6AEA0E33BBFF 1st Glorious Mystery: The Resurrection
# 98.04 D47559AB-D281-BE34-1899-6928AA0FEEC1 Der Schwarm (Teil 98)
# 98.04 A259F5BA-8678-B8D2-179E-098B3DC1B5A2 Der Schwarm (Teil 53)
# 98.04 0A37F60C-B3FE-3B21-7C7F-436100471FAE Der Schwarm (Teil 116)
# 98.04 FB7733FB-75C3-381D-A329-259DC59D846E Der Schwarm (Teil 114)
# 98.04 8699723A-EAF0-F12A-C928-AA7DB8F78279 "Ah, Hier Sind Wir Ja Schon"
# 98.04 B04B90A8-EF21-D10C-3291-BDD898E06D0F Der Schwarm (Teil 55)
# 98.04 D6391B12-A940-F4A5-9A0A-B694AAAE58DA Der Schwarm (Teil 77)
# 98.04 0EF63D5B-069D-C363-A5DA-74123152D101 Der Schwarm (Teil 24)
# 98.04 398D83B3-9CF7-31D7-0F01-BA3B959A6BCA Der Schwarm (Teil 47)
# 98.04 EEF936C7-EE1F-BEA4-8230-B433471B8881 Tonight's The Kind Of Night
# 98.04 7B3DFD94-842E-C52E-917A-4CCDDA911E9B The Revolution Medley: The Revolution Will Not Be Televised / Lose Yourself / Once In A Lifetime
# 98.04 6526B403-C414-21ED-F22E-3273DADD984E 4th Mystery: The Carrying Of The Cross
# 98.04 BE659F18-7831-A720-437F-D068EF90CC3E She's Not You
# 96.85 5D035176-92BD-BCD3-7FB5-124D6EB8FDF9 Kissing Tree
# 96.85 F7709770-C239-F89A-91DA-E6F80B45F091 Flames Of Truth
# 96.85 531F0E8E-A174-F51D-90B4-9B2A6A1D9314 Break Hard The Wishbone
# 96.85 C785D1E8-2117-FE83-9642-107F639E9D8A Fly Baby

# %% [markdown]
# <b>To get the track's details and the artists, albums, properties, etc., use the 'tracks/search' call using these UIDs.</b>

# %% [markdown]
# ## List Properties (Moods, etc.)

# %%
#  more track examples
